# %%
#18.9. potentially filter out adverbes, words commonly used in titles like 'reveal', 'evidence', 'high', 'study'

# %%
from Bio import SeqIO
from collections import Counter
import pandas as pd 
import re
import requests
import json
import time
import glob
import pprint
import seaborn as sns
import pylab as plt
from matplotlib.ticker import MaxNLocator
from matplotlib.colors import ListedColormap
import pycountry 
import pycountry_convert as pc
pp = pprint.PrettyPrinter()
import numpy as np
from tabulate import tabulate
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon
import regex as re
import plotly.graph_objects as go
import os

from string import punctuation
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
import nltk
from bs4 import BeautifulSoup


 

stemmer=SnowballStemmer("english")
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import networkx as nx
from collections import defaultdict
from itertools import combinations
from fa2 import ForceAtlas2

import textmining
  

# %env folder = X:\5_Research\Paul\dsi_origins\
# Out:
# env: folder=X:\5_Research\Paul\dsi_origins\

# %%
path = %env folder

# %% [markdown]
# ### 1. Data pre-processing

# %%
df_scholarly = pd.read_csv(path+R'processed_data\scholarly_aff_country.csv', index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-1ee316e32ae8> in <module>
# ----> 1 df_scholarly = pd.read_csv(path+R'processed_data\scholarly_aff_country.csv', index_col = 0)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     581
#     582     with parser:
# --> 583         return parser.read(nrows)
#     584
#     585
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df_scholarly.head()

# %%
len(set(df_scholarly['id_select']))
# Out:
# 99179

# %%
#explore how many publication have titles, keywords, abstracts, fulltext
len(set(df_scholarly['id_select'][~df_scholarly['title'] != '']))
# Out:
# 99179

# %%
#explore how many publication have titles, keywords, abstracts, fulltext
len(set(df_scholarly['id_select'][df_scholarly['abstract'] != '']))
# Out:
# 99179

# %%
#explore how many publication have titles, keywords, abstracts, fulltext
len(set(df_scholarly['id_select'][df_scholarly['keywords'] != '']))
# Out:
# 99179

# %%
set(df_scholarly['id_select'][df_scholarly['keywords'] != ''])
# Out:
# {'pmc6520331',
#  '20305031.0',
#  '35741706.0',
#  '23396159.0',
#  '20558015.0',
#  'pmc3386335',
#  '10902725.0',
#  'pmc3692544',
#  '23868922.0',
#  '27544241.0',
#  '19073734.0',
#  '27272684.0',
#  '19751581.0',
#  'pmc3463576',
#  '23073850.0',
#  '24071658.0',
#  'pmc4291760',
#  'pmc4429459',
#  '10.1111/j.1439-0434.2009.01615.x',
#  'pmc3942966',
#  'pmc6469090',
#  '15812036.0',
#  '11004569.0',
#  '24709084.0',
#  '23266980.0',
#  '24914799.0',
#  '17925860.0',
#  '27536332.0',
#  '17267951.0',
#  '22524539.0',
#  '21460134.0',
#  'pmc4959245',
#  '23664726.0',
#  '23111094.0',
#  '22524407.0',
#  '34323385.0',
#  '17675445.0',
#  '16207958.0',
#  'pmc4274890',
#  '30499769.0',
#  '23888863.0',
#  '29299848.0',
#  '23166228.0',
#  '36203558.0',
#  '28857036.0',
#  '18948297.0',
#  '25882833.0',
#  '32193231.0',
#  'pmc5004317',
#  '33853647.0',
#  'pmc4746201',
#  '10.1007/s10327-008-0107-3',
#  '31137836.0',
#  '11055970.0',
#  '34283016.0',
#  '24102608.0',
#  '30397141.0',
#  'pmc6156297',
#  '25600751.0',
#  'pmc1610281',
#  '19453981.0',
#  'pmc6533538',
#  '17942098.0',
#  'pmc1472213',
#  '25879186.0',
#  '23663295.0',
#  '15056364.0',
#  '36459866.0',
#  '17116685.0',
#  '27234556.0',
#  '24812362.0',
#  '15901487.0',
#  '20596837.0',
#  'pmc3931355',
#  '30731820.0',
#  'pmc6445280',
#  'pmc2935072',
#  'pmc4373515',
#  '23797143.0',
#  '22337294.0',
#  '23212939.0',
#  'pmc4752944',
#  'pmc5154165',
#  '25038295.0',
#  '21749781.0',
#  'pmc3668654',
#  'pmc5633087',
#  '24379021.0',
#  '20975720.0',
#  '18325125.0',
#  '26136578.0',
#  '23417223.0',
#  '18599724.0',
#  '24903873.0',
#  '17004028.0',
#  '29080673.0',
#  '21775584.0',
#  'pmc5466663',
#  'pmc5461048',
#  '19136224.0',
#  '22476900.0',
#  'pmc4066810',
#  '20005155.0',
#  '20410937.0',
#  'pmc4109512',
#  '26841717.0',
#  '30856252.0',
#  '20543153.0',
#  '31844412.0',
#  'pmc6547736',
#  'pmc2854153',
#  '29913249.0',
#  '17412685.0',
#  '16246910.0',
#  '19042097.0',
#  '23079816.0',
#  '14690509.0',
#  '30671580.0',
#  '23152747.0',
#  '21671082.0',
#  '17334858.0',
#  'pmc3735576',
#  'pmc5490812',
#  'pmc1280207',
#  '33811217.0',
#  '20553426.0',
#  '12207731.0',
#  '23015746.0',
#  'pmc5658510',
#  '25915755.0',
#  '21310557.0',
#  '17965205.0',
#  '36101131.0',
#  '17849710.0',
#  '10.1111/j.1365-2699.2006.01672.x',
#  '22035191.0',
#  '17547676.0',
#  '19539673.0',
#  '29411387.0',
#  '38589385.0',
#  '25454469.0',
#  '20977744.0',
#  'pmc5441638',
#  'pmc3221667',
#  'pmc4231363',
#  '17220267.0',
#  'pmc4649276',
#  'pmc6256681',
#  '10.1007/s10592-007-9394-z',
#  '18986494.0',
#  '21359845.0',
#  'pmc6610546',
#  '27639933.0',
#  'pmc6179053',
#  'pmc137026',
#  '10.1016/j.soilbio.2004.02.017',
#  '24040199.0',
#  '16563458.0',
#  '22612430.0',
#  'pmc5977210',
#  '10.1111/j.1439-0434.2006.01178.x',
#  '18984006.0',
#  '26779153.0',
#  '31401696.0',
#  '30708904.0',
#  '22092809.0',
#  '30600350.0',
#  '12470940.0',
#  'pmc2847566',
#  '22237545.0',
#  '28839025.0',
#  'pmc5412350',
#  'pmc4181792',
#  '32164546.0',
#  'pmc4691136',
#  '32317015.0',
#  '29571411.0',
#  '20402779.0',
#  '15388959.0',
#  '26041280.0',
#  '25090432.0',
#  '20511467.0',
#  'pmc4865086',
#  '22354973.0',
#  '28630462.0',
#  '24535281.0',
#  'pmc6138182',
#  '25733490.0',
#  '35580787.0',
#  'pmc5560572',
#  'pmc2871887',
#  '23606763.0',
#  '23709574.0',
#  '24070785.0',
#  '19821634.0',
#  '22008698.0',
#  '28376092.0',
#  'pmc4923064',
#  '25804761.0',
#  '11955782.0',
#  '35756069.0',
#  '33893550.0',
#  '24870466.0',
#  'pmc3131650',
#  '20540741.0',
#  '29469688.0',
#  '10930068.0',
#  '36175794.0',
#  '23571508.0',
#  '22107351.0',
#  '18237261.0',
#  'pmc5797404',
#  '21223328.0',
#  '34271527.0',
#  '18726520.0',
#  '21402448.0',
#  'pmc6505909',
#  '31601038.0',
#  'pmc5941679',
#  '18201745.0',
#  '35493754.0',
#  '21659236.0',
#  'pmc5666284',
#  '31578566.0',
#  '28828706.0',
#  '16990803.0',
#  '16563200.0',
#  'pmc6612549',
#  '10.1111/j.1471-8286.2004.00766.x',
#  '25224356.0',
#  'pmc5346831',
#  'pmc4168257',
#  '27249649.0',
#  '27473771.0',
#  '23435251.0',
#  '26000447.0',
#  '24021726.0',
#  '16738090.0',
#  '16911197.0',
#  'pmc6200565',
#  '27808472.0',
#  '26530992.0',
#  '20107013.0',
#  '12165846.0',
#  '11888657.0',
#  '16876698.0',
#  '21963364.0',
#  '18344350.0',
#  '33575895.0',
#  '23770897.0',
#  '26067293.0',
#  '27486075.0',
#  '22119387.0',
#  '19220395.0',
#  '25204600.0',
#  '33465074.0',
#  '31199457.0',
#  '16384661.0',
#  '29249199.0',
#  '11429128.0',
#  '35959365.0',
#  '38805031.0',
#  '17516529.0',
#  '30388658.0',
#  '23441179.0',
#  'pmc6256631',
#  '17943392.0',
#  '24647552.0',
#  '29476907.0',
#  '23828012.0',
#  '16978174.0',
#  '26508717.0',
#  ...}

# %%
title_id_df =df_scholarly[['title','id_select']].drop_duplicates()
title_id_dict = dict(zip(title_id_df['title'], title_id_df['id_select']))

# %%
titles_nodup = list(set(df_scholarly['title'].dropna()))

# %%
len(titles_nodup)
# Out:
# 99179

# %%
# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Function to map NLTK POS tags to WordNet POS tags
def get_wordnet_pos(nltk_pos_tag):
    if nltk_pos_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_pos_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_pos_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Default to noun

# Function to lemmatize a title with POS tagging
def lemmatize_title(title):
    words = word_tokenize(title.lower())
    pos_tagged_words = nltk.pos_tag(words)
    
    lemmatized_words = [
        lemmatizer.lemmatize(word, get_wordnet_pos(pos_tag)) 
        for word, pos_tag in pos_tagged_words
    ]
    
    return ' '.join(lemmatized_words)

lemmatized_titles = []


for title in titles_nodup: 
    lemmatized_title = lemmatize_title(title)
    lemmatized_titles.append(lemmatized_title)

# %%
# Define the set of spelled-out numbers to remove
spelled_out_numbers = {'zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten',
                       'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen',
                       'nineteen', 'twenty', 'thirty', 'forty', 'fifty', 'sixty', 'seventy', 'eighty', 'ninety', 
                       'hundred', 'thousand', 'million', 'billion','first', 'firstly', 'second', 'secondly', 'third', 'thirdly'}

# Define the set of countries, geographic regions, and their adjectives (demonyms) to remove
countries_and_regions = {'afghanistan', 'albania', 'algeria', 'andorra', 'angola', 'argentina', 'armenia', 'australia', 
                         'austria', 'azerbaijan', 'bahamas', 'bahrain', 'bangladesh', 'barbados', 'belarus', 'belgium', 
                         'belize', 'benin', 'bhutan', 'bolivia', 'bosnia', 'botswana', 'brazil', 'bulgaria', 'burkina', 
                         'burundi', 'cambodia', 'cameroon', 'canada', 'chad', 'chile', 'china', 'colombia', 'comoros', 
                         'congo', 'costa rica', 'croatia', 'cuba', 'cyprus', 'czech', 'denmark', 'djibouti', 'dominica', 'ecuador', 
                         'egypt', 'eritrea', 'estonia', 'eswatini', 'ethiopia', 'fiji', 'finland', 'france', 'gabon', 
                         'gambia', 'georgia', 'germany', 'ghana', 'greece', 'grenada', 'guatemala', 'guinea', 'guyana', 
                         'haiti', 'honduras', 'hungary', 'iceland', 'india', 'indonesia', 'iran', 'iraq', 'ireland', 
                         'israel', 'italy', 'jamaica', 'japan', 'jordan', 'kazakhstan', 'kenya', 'kiribati', 'kuwait', 
                         'kyrgyzstan', 'laos', 'latvia', 'lebanon', 'lesotho', 'liberia', 'libya', 'liechtenstein', 
                         'lithuania', 'luxembourg', 'madagascar', 'malawi', 'malaysia', 'maldives', 'mali', 'malta', 
                         'mauritania', 'mauritius', 'mexico', 'moldova', 'monaco', 'mongolia', 'montenegro', 'morocco', 
                         'mozambique', 'myanmar', 'namibia', 'nepal', 'netherlands', 'new zealand', 'nicaragua', 'niger', 
                         'nigeria', 'north korea', 'north macedonia', 'norway', 'oman', 'pakistan', 'palau', 'panama', 
                         'papua new guinea', 'paraguay', 'peru', 'philippines', 'poland', 'portugal', 'qatar', 'romania', 
                         'russia', 'rwanda', 'samoa', 'san marino', 'saudi arabia', 'senegal', 'serbia', 'seychelles', 
                         'sierra leone', 'singapore', 'slovakia', 'slovenia', 'somalia', 'south africa', 'south korea', 
                         'spain', 'sri lanka', 'sudan', 'suriname', 'sweden', 'switzerland', 'syria', 'tajikistan', 
                         'tanzania', 'thailand', 'togo', 'tonga', 'tunisia', 'turkey', 'turkmenistan', 'uganda', 'ukraine', 
                         'united arab emirates', 'united kingdom', 'united states', 'uruguay', 'uzbekistan', 'vanuatu', 
                         'venezuela', 'vietnam', 'yemen', 'zambia', 'zimbabwe',
                         # Geographic regions
                         'africa', 'asia', 'europe', 'america', 'north america', 'south america', 'oceania', 'antarctica', 
                         'middle east', 'eastern europe', 'western europe', 'northern europe', 'southern europe', 'latin america'}

# Add country-based adjectives (demonyms) to the list
demonyms = {'afghan', 'albanian', 'algerian', 'andorran', 'angolan', 'argentine', 'armenian', 'australian', 'austrian',
            'azerbaijani', 'bahamian', 'bahraini', 'bangladeshi', 'barbadian', 'belarusian', 'belgian', 'belizean', 
            'beninese', 'bhutanese', 'bolivian', 'bosnian', 'botswanan', 'brazilian', 'bulgarian', 'burkinabe', 
            'burundian', 'cambodian', 'cameroonian', 'canadian', 'chadian', 'chilean', 'chinese', 'colombian', 'comorian', 
            'congolese', 'costa rican','croatian', 'cuban', 'cypriot', 'czech', 'danish', 'djiboutian', 'dominican', 'ecuadorian', 
            'egyptian', 'eritrean', 'estonian', 'eswatini', 'ethiopian', 'fijian', 'finnish', 'french', 'gabonese', 
            'gambian', 'georgian', 'german', 'ghanaian', 'greek', 'grenadian', 'guatemalan', 'guinean', 'guyanese', 
            'haitian', 'honduran', 'hungarian', 'icelandic', 'indian', 'indonesian', 'iranian', 'iraqi', 'irish', 
            'israeli', 'italian', 'jamaican', 'japanese', 'jordanian', 'kazakh', 'kenyan', 'kiribati', 'kuwaiti', 
            'kyrgyz', 'laotian', 'latvian', 'lebanese', 'lesothan', 'liberian', 'libyan', 'liechtensteiner', 'lithuanian', 
            'luxembourger', 'malagasy', 'malawian', 'malaysian', 'maldivian', 'malian', 'maltese', 'mauritanian', 
            'mauritian', 'mexican', 'moldovan', 'monacan', 'mongolian', 'montenegrin', 'moroccan', 'mozambican', 'myanmarese', 
            'namibian', 'nepalese', 'dutch', 'new zealander', 'nicaraguan', 'nigerien', 'nigerian', 'north korean', 
            'macedonian', 'norwegian', 'omani', 'pakistani', 'palauan', 'panamanian', 'papua new guinean', 'paraguayan', 
            'peruvian', 'philippine', 'polish', 'portuguese', 'qatari', 'romanian', 'russian', 'rwandan', 'samoan', 
            'san marinese', 'saudi', 'senegalese', 'serbian', 'seychellois', 'sierra leonean', 'singaporean', 'slovak', 
            'slovenian', 'somali', 'south african', 'south korean', 'spanish', 'sri lankan', 'sudanese', 'surinamese', 
            'swazi', 'swedish', 'swiss', 'syrian', 'tajik', 'tanzanian', 'thai', 'togolese', 'tongan', 'tunisian', 
            'turkish', 'turkmen', 'ugandan', 'ukrainian', 'emirati', 'british', 'american', 'uruguayan', 'uzbek', 
            'vanuatuan', 'venezuelan', 'vietnamese', 'yemeni', 'zambian', 'zimbabwean', 'african', 'asian', 'european',  'mediterrenean', 'pacific', 'atlantic', 'usa', 'korea', 'republic', 'taiwan'}

# Merge countries, regions, and demonyms into a single set for filtering
countries_regions_demonyms = countries_and_regions.union(demonyms)

# Define additional stopwords if needed
own_stopwords = ['ci', 'sp', 'spp', 'title', 'summary', 'background','north', 'northern', 'south','southern','east','eastern','west','western', 'southwest', 'southeastern','southwest','southwestern', 'northeast','northeastern', 'northwest','northwestern',  'et', 'al', 'de', 'ii']
mystopwords = stopwords.words("english") + own_stopwords


titles_cleaned_stopwords = []


# Remove countries, regions, adjectives, numbers (written and actual), and other unwanted words
words_counter = Counter()
for title in lemmatized_titles:
    title_clean = ''
    for word in title.split():
        word_cleaned = "".join([l for l in word if l not in punctuation]).lower()
        
        # Remove stopwords, digits, spelled-out numbers, country names, regions, and adjectives (demonyms)
        if (word_cleaned not in mystopwords and 
            not word_cleaned.isdigit() and 
            word_cleaned not in spelled_out_numbers and 
            word_cleaned not in countries_regions_demonyms and 
            len(word_cleaned) > 1):
            #if word_cleaned in replace_dict.keys(): 
            #    word_cleaned = replace_dict[word_cleaned]
            
            if title_clean == '':
                title_clean = word_cleaned
            else:
                title_clean = title_clean + ' ' + word_cleaned
                
    titles_cleaned_stopwords.append(title_clean)
    words_counter.update(list(set(title_clean.split())))
titles_cleaned_stopwords[:10]
# Out:
# ['scchi encode acidic class iii chitinase sugarcane confers positive response biotic abiotic stress sugarcane',
#  'fine taxonomic sampling nervous system within naididae annelida clitellata reveal evolutionary lability revised homology annelid neural component',
#  'novel integron salmonella enterica serovar enteritidis carry bla dha1 gene regulator gene ampr originate morganella morganii',
#  'highly pathogenic avian influenza virus infection chicken duck associate elevated host immune proinflammatory response',
#  'mariniflexile soesokkakense nov member family flavobacteriaceae isolate junction ocean freshwater spring emend description genus mariniflexile',
#  'comparative genome analysis spiroplasma melliferum ipmb4a honeybeeassociated bacterium',
#  'study visceral leishmaniasis owned dog dermal lesion mashhad area khorasan razavi province',
#  'thiomicrorhabdus aquaedulcis nov sulfuroxidizing bacterium isolate lake water',
#  'biocontrol agent promote growth potato pathogen depend environmental condition',
#  'genome sequence isolates yellow oatgrass mosaic virus new grassinfecting tritimovirus']

# %%
clestp_ori_title_dict = dict(zip(titles_cleaned_stopwords, titles_nodup))

# %%
words_counter.most_common()
# Out:
# [('virus', 15027),
#  ('isolate', 10120),
#  ('molecular', 9694),
#  ('characterization', 9299),
#  ('specie', 8542),
#  ('sequence', 8504),
#  ('gene', 8319),
#  ('analysis', 7724),
#  ('new', 7186),
#  ('genome', 6900),
#  ('novel', 6543),
#  ('genetic', 6246),
#  ('nov', 6232),
#  ('strain', 6216),
#  ('diversity', 5924),
#  ('human', 4639),
#  ('identification', 4553),
#  ('infection', 4257),
#  ('complete', 3942),
#  ('phylogenetic', 3909),
#  ('detection', 3766),
#  ('dna', 3344),
#  ('type', 3334),
#  ('genus', 3252),
#  ('associate', 3057),
#  ('population', 2819),
#  ('use', 2799),
#  ('disease', 2786),
#  ('isolates', 2689),
#  ('mitochondrial', 2610),
#  ('soil', 2530),
#  ('evolution', 2509),
#  ('resistance', 2485),
#  ('community', 2372),
#  ('protein', 2365),
#  ('phylogeny', 2262),
#  ('among', 2231),
#  ('evidence', 2208),
#  ('genotype', 2186),
#  ('bacteria', 2129),
#  ('report', 2121),
#  ('hepatitis', 2109),
#  ('isolation', 2101),
#  ('patient', 2067),
#  ('cause', 2057),
#  ('region', 2012),
#  ('influenza', 1981),
#  ('expression', 1972),
#  ('reveal', 1947),
#  ('bacterial', 1878),
#  ('plant', 1831),
#  ('host', 1794),
#  ('structure', 1779),
#  ('study', 1775),
#  ('genomic', 1769),
#  ('bacterium', 1738),
#  ('infect', 1728),
#  ('description', 1692),
#  ('marine', 1685),
#  ('base', 1616),
#  ('high', 1602),
#  ('family', 1592),
#  ('hiv1', 1580),
#  ('group', 1552),
#  ('distribution', 1519),
#  ('outbreak', 1455),
#  ('avian', 1439),
#  ('prevalence', 1439),
#  ('complex', 1433),
#  ('variation', 1432),
#  ('cell', 1406),
#  ('clinical', 1401),
#  ('wild', 1381),
#  ('variant', 1358),
#  ('relationship', 1350),
#  ('potential', 1336),
#  ('different', 1335),
#  ('morphological', 1319),
#  ('microbial', 1312),
#  ('gen', 1304),
#  ('porcine', 1263),
#  ('evolutionary', 1262),
#  ('case', 1254),
#  ('activity', 1252),
#  ('sequencing', 1241),
#  ('development', 1240),
#  ('transmission', 1226),
#  ('viral', 1213),
#  ('mutation', 1212),
#  ('within', 1192),
#  ('origin', 1182),
#  ('water', 1177),
#  ('lineage', 1154),
#  ('pattern', 1154),
#  ('pathogen', 1147),
#  ('reveals', 1130),
#  ('multiple', 1101),
#  ('tick', 1074),
#  ('fish', 1064),
#  ('cloning', 1057),
#  ('recombinant', 1055),
#  ('acid', 1054),
#  ('rna', 1051),
#  ('sea', 1045),
#  ('effect', 1041),
#  ('comparative', 1040),
#  ('hiv', 1039),
#  ('production', 1039),
#  ('sediment', 1038),
#  ('respiratory', 1037),
#  ('child', 1035),
#  ('lake', 1033),
#  ('parasite', 1031),
#  ('response', 1005),
#  ('natural', 1002),
#  ('insight', 989),
#  ('pcr', 989),
#  ('epidemiology', 980),
#  ('sample', 973),
#  ('bacillus', 971),
#  ('central', 958),
#  ('island', 947),
#  ('highly', 928),
#  ('fever', 927),
#  ('system', 914),
#  ('coli', 913),
#  ('rotavirus', 904),
#  ('state', 901),
#  ('fungi', 896),
#  ('member', 895),
#  ('marker', 895),
#  ('identify', 891),
#  ('functional', 890),
#  ('comparison', 888),
#  ('data', 885),
#  ('pseudomonas', 884),
#  ('leaf', 876),
#  ('subtype', 865),
#  ('escherichia', 863),
#  ('freshwater', 857),
#  ('fungal', 853),
#  ('assay', 833),
#  ('pig', 830),
#  ('implication', 828),
#  ('history', 818),
#  ('immunodeficiency', 817),
#  ('acute', 812),
#  ('polymorphism', 801),
#  ('dynamic', 796),
#  ('province', 794),
#  ('diptera', 794),
#  ('pathogenic', 789),
#  ('mosaic', 782),
#  ('vaccine', 781),
#  ('infectious', 778),
#  ('nuclear', 769),
#  ('fungus', 767),
#  ('bat', 767),
#  ('bovine', 766),
#  ('cattle', 763),
#  ('field', 757),
#  ('dog', 756),
#  ('swine', 755),
#  ('forest', 753),
#  ('drug', 749),
#  ('syndrome', 744),
#  ('detect', 731),
#  ('role', 731),
#  ('distinct', 723),
#  ('rapid', 716),
#  ('characterisation', 707),
#  ('phylogeography', 705),
#  ('approach', 705),
#  ('cryptic', 701),
#  ('yellow', 699),
#  ('growth', 698),
#  ('plasmid', 693),
#  ('factor', 685),
#  ('plasmodium', 684),
#  ('change', 681),
#  ('characteristic', 678),
#  ('produce', 676),
#  ('environmental', 675),
#  ('variability', 670),
#  ('common', 662),
#  ('united', 657),
#  ('method', 644),
#  ('emergence', 642),
#  ('endemic', 631),
#  ('chicken', 630),
#  ('selection', 630),
#  ('epidemic', 628),
#  ('evaluation', 626),
#  ('rrna', 625),
#  ('environment', 621),
#  ('cryptosporidium', 619),
#  ('association', 619),
#  ('blood', 619),
#  ('small', 616),
#  ('domestic', 616),
#  ('encode', 613),
#  ('diverse', 613),
#  ('recombination', 610),
#  ('nucleotide', 607),
#  ('culture', 605),
#  ('occurrence', 603),
#  ('bird', 600),
#  ('root', 596),
#  ('barcoding', 589),
#  ('area', 585),
#  ('differentiation', 584),
#  ('yeast', 582),
#  ('taxonomic', 579),
#  ('mosquito', 575),
#  ('morphology', 573),
#  ('clade', 573),
#  ('canine', 573),
#  ('spot', 571),
#  ('vector', 571),
#  ('major', 569),
#  ('infer', 561),
#  ('low', 561),
#  ('tree', 556),
#  ('dengue', 556),
#  ('ribosomal', 554),
#  ('enterovirus', 554),
#  ('locus', 553),
#  ('circulate', 552),
#  ('divergence', 552),
#  ('surface', 550),
#  ('mouse', 548),
#  ('control', 548),
#  ('treatment', 548),
#  ('antibody', 547),
#  ('virulence', 534),
#  ('microsatellite', 531),
#  ('endophytic', 525),
#  ('realtime', 524),
#  ('rice', 522),
#  ('taxonomy', 521),
#  ('diversification', 521),
#  ('relate', 519),
#  ('newly', 517),
#  ('streptomyces', 514),
#  ('involve', 511),
#  ('tomato', 511),
#  ('application', 511),
#  ('biological', 511),
#  ('red', 507),
#  ('surveillance', 507),
#  ('river', 507),
#  ('multilocus', 507),
#  ('nematode', 501),
#  ('cluster', 498),
#  ('staphylococcus', 496),
#  ('animal', 492),
#  ('agent', 491),
#  ('survey', 485),
#  ('serotype', 483),
#  ('receptor', 482),
#  ('diarrhea', 481),
#  ('discovery', 478),
#  ('genotyping', 477),
#  ('single', 477),
#  ('composition', 474),
#  ('impact', 473),
#  ('norovirus', 472),
#  ('rickettsia', 469),
#  ('anaerobic', 464),
#  ('mediterranean', 463),
#  ('fruit', 460),
#  ('emerge', 460),
#  ('large', 460),
#  ('class', 458),
#  ('source', 452),
#  ('model', 452),
#  ('clone', 452),
#  ('vitro', 452),
#  ('across', 448),
#  ('antimicrobial', 448),
#  ('biogeography', 447),
#  ('reproductive', 446),
#  ('assessment', 445),
#  ('epidemiological', 444),
#  ('ancient', 444),
#  ('farm', 444),
#  ('putative', 441),
#  ('record', 440),
#  ('tropical', 436),
#  ('include', 435),
#  ('related', 428),
#  ('form', 428),
#  ('adenovirus', 428),
#  ('gastroenteritis', 427),
#  ('rdna', 426),
#  ('nematoda', 425),
#  ('fly', 423),
#  ('polymerase', 423),
#  ('vibrio', 419),
#  ('bacteriophage', 418),
#  ('early', 418),
#  ('frog', 416),
#  ('coastal', 416),
#  ('candidatus', 414),
#  ('profile', 413),
#  ('collect', 412),
#  ('site', 411),
#  ('amplification', 410),
#  ('presence', 410),
#  ('pathway', 409),
#  ('level', 409),
#  ('enzyme', 408),
#  ('fusarium', 407),
#  ('lepidoptera', 407),
#  ('investigation', 406),
#  ('cat', 405),
#  ('recent', 405),
#  ('duck', 404),
#  ('malaria', 404),
#  ('unique', 404),
#  ('black', 403),
#  ('degradation', 403),
#  ('specific', 402),
#  ('subtypes', 399),
#  ('range', 399),
#  ('suggest', 399),
#  ('pneumoniae', 398),
#  ('susceptibility', 394),
#  ('reverse', 393),
#  ('tissue', 392),
#  ('antiretroviral', 391),
#  ('chloroplast', 390),
#  ('sheep', 389),
#  ('beetle', 389),
#  ('potato', 387),
#  ('encephalitis', 387),
#  ('deep', 387),
#  ('mechanism', 386),
#  ('therapy', 386),
#  ('phage', 383),
#  ('phenotypic', 383),
#  ('invasive', 382),
#  ('rodent', 381),
#  ('individual', 381),
#  ('influence', 381),
#  ('interaction', 381),
#  ('provide', 381),
#  ('speciation', 380),
#  ('anaplasma', 380),
#  ('rot', 377),
#  ('halophilic', 377),
#  ('adaptation', 376),
#  ('rhizosphere', 376),
#  ('target', 376),
#  ('property', 376),
#  ('inhibitor', 375),
#  ('severe', 374),
#  ('biosynthesis', 372),
#  ('pathogenicity', 372),
#  ('spring', 371),
#  ('klebsiella', 371),
#  ('babesia', 371),
#  ('protease', 369),
#  ('zoonotic', 369),
#  ('acinetobacter', 369),
#  ('streptococcus', 368),
#  ('gut', 367),
#  ('naturally', 363),
#  ('coleoptera', 362),
#  ('chain', 361),
#  ('coronavirus', 361),
#  ('anopheles', 361),
#  ('divergent', 361),
#  ('insect', 360),
#  ('green', 360),
#  ('thermophilic', 359),
#  ('native', 359),
#  ('ocean', 357),
#  ('parvovirus', 356),
#  ('structural', 355),
#  ('find', 354),
#  ('antibiotic', 351),
#  ('teleostei', 351),
#  ('affect', 351),
#  ('element', 349),
#  ('support', 349),
#  ('ecological', 348),
#  ('metagenomic', 348),
#  ('adult', 348),
#  ('antigen', 346),
#  ('wastewater', 345),
#  ('stress', 343),
#  ('hospital', 342),
#  ('rabies', 342),
#  ('fulllength', 342),
#  ('replication', 341),
#  ('brown', 341),
#  ('tickborne', 341),
#  ('mycobacterium', 340),
#  ('increase', 340),
#  ('global', 338),
#  ('cytochrome', 335),
#  ('genotypic', 335),
#  ('hemiptera', 334),
#  ('subsp', 333),
#  ('condition', 332),
#  ('geographic', 331),
#  ('aureus', 330),
#  ('rate', 328),
#  ('function', 328),
#  ('hybridization', 328),
#  ('falciparum', 327),
#  ('specificity', 327),
#  ('borrelia', 326),
#  ('herpesvirus', 326),
#  ('immune', 325),
#  ('spread', 325),
#  ('coral', 324),
#  ('h5n1', 324),
#  ('aeruginosa', 324),
#  ('risk', 323),
#  ('express', 323),
#  ('diagnosis', 323),
#  ('circovirus', 322),
#  ('widespread', 320),
#  ('taxon', 319),
#  ('california', 318),
#  ('show', 316),
#  ('habitat', 316),
#  ('typing', 316),
#  ('conservation', 316),
#  ('digenea', 314),
#  ('systematics', 314),
#  ('salmonella', 313),
#  ('h1n1', 313),
#  ('aspergillus', 313),
#  ('anura', 311),
#  ('mycorrhizal', 309),
#  ('position', 309),
#  ('chronic', 309),
#  ('primary', 308),
#  ('dispersal', 306),
#  ('draft', 305),
#  ('reservoir', 304),
#  ('lactobacillus', 304),
#  ('primer', 303),
#  ('actinomycete', 301),
#  ('hybrid', 301),
#  ('salt', 300),
#  ('test', 299),
#  ('formation', 298),
#  ('grapevine', 298),
#  ('candidate', 298),
#  ('ixodes', 297),
#  ('world', 297),
#  ('emend', 296),
#  ('transfer', 296),
#  ('infected', 294),
#  ('papillomavirus', 294),
#  ('antigenic', 294),
#  ('classification', 294),
#  ('purification', 293),
#  ('whole', 292),
#  ('derive', 292),
#  ('hemorrhagic', 292),
#  ('domain', 292),
#  ('closely', 291),
#  ('contain', 290),
#  ('goat', 290),
#  ('differential', 290),
#  ('year', 289),
#  ('internal', 288),
#  ('neotropical', 288),
#  ('endanger', 287),
#  ('along', 287),
#  ('equine', 287),
#  ('resistant', 287),
#  ('repeat', 287),
#  ('partial', 287),
#  ('rare', 286),
#  ('giardia', 286),
#  ('cdna', 285),
#  ('drosophila', 283),
#  ('via', 281),
#  ('transcription', 281),
#  ('larva', 281),
#  ('deepsea', 280),
#  ('sex', 280),
#  ('nile', 280),
#  ('biodiversity', 279),
#  ('coast', 279),
#  ('carry', 278),
#  ('wheat', 278),
#  ('feature', 278),
#  ('allele', 278),
#  ('korean', 278),
#  ('peptide', 277),
#  ('induce', 277),
#  ('life', 276),
#  ('active', 276),
#  ('subunit', 276),
#  ('seawater', 276),
#  ('colonization', 275),
#  ('deer', 275),
#  ('difference', 274),
#  ('basin', 273),
#  ('unusual', 273),
#  ('link', 273),
#  ('reaction', 271),
#  ('sensu', 271),
#  ('poultry', 269),
#  ('process', 269),
#  ('revision', 268),
#  ('event', 267),
#  ('ruminant', 266),
#  ('organization', 266),
#  ('tract', 265),
#  ('candida', 265),
#  ('bartonella', 264),
#  ('possible', 263),
#  ('newcastle', 263),
#  ('hot', 262),
#  ('spacer', 262),
#  ('hymenoptera', 262),
#  ('genomics', 262),
#  ('aedes', 262),
#  ('screening', 261),
#  ('pandemic', 261),
#  ('chromosome', 261),
#  ('white', 261),
#  ('due', 260),
#  ('abundance', 259),
#  ('geographical', 258),
#  ('wholegenome', 258),
#  ('great', 258),
#  ('rat', 258),
#  ('leishmania', 257),
#  ('mountain', 257),
#  ('genetics', 257),
#  ('secondary', 256),
#  ('circulation', 256),
#  ('time', 256),
#  ('radiation', 256),
#  ('skin', 255),
#  ('antarctic', 255),
#  ('phylogenetics', 254),
#  ('mtdna', 253),
#  ('mammal', 253),
#  ('spatial', 253),
#  ('wolbachia', 253),
#  ('heterogeneity', 253),
#  ('determine', 252),
#  ('sponge', 252),
#  ('envelope', 251),
#  ('food', 251),
#  ('library', 251),
#  ('oil', 251),
#  ('parasitic', 250),
#  ('introduction', 249),
#  ('status', 249),
#  ('zealand', 247),
#  ('live', 247),
#  ('improve', 247),
#  ('follow', 245),
#  ('reference', 245),
#  ('segment', 245),
#  ('ciliophora', 244),
#  ('stem', 244),
#  ('fragment', 243),
#  ('lizard', 243),
#  ('feline', 241),
#  ('cycle', 241),
#  ('shrimp', 241),
#  ('curl', 241),
#  ('echinococcus', 241),
#  ('glycoprotein', 241),
#  ('footandmouth', 240),
#  ('historical', 240),
#  ('desert', 240),
#  ('arctic', 240),
#  ('virulent', 240),
#  ('commercial', 239),
#  ('biochemical', 239),
#  ('microbiota', 239),
#  ('phylogeographic', 239),
#  ('phytoplasma', 238),
#  ('bee', 238),
#  ('chikungunya', 237),
#  ('subgroup', 237),
#  ('product', 237),
#  ('culicidae', 237),
#  ('symbiotic', 236),
#  ('specimen', 236),
#  ('determinant', 236),
#  ('important', 235),
#  ('occur', 235),
#  ('expansion', 235),
#  ('horse', 234),
#  ('quantitative', 234),
#  ('sludge', 233),
#  ('ant', 232),
#  ('line', 232),
#  ('vivo', 232),
#  ('key', 232),
#  ('citrus', 231),
#  ('cyanobacteria', 231),
#  ('archaea', 231),
#  ('healthy', 230),
#  ('ectomycorrhizal', 230),
#  ('enhance', 230),
#  ('baumannii', 229),
#  ('membrane', 229),
#  ('amino', 229),
#  ('transcriptome', 228),
#  ('biodegradation', 228),
#  ('mycoplasma', 228),
#  ('giant', 228),
#  ('tool', 227),
#  ('harbor', 227),
#  ('stage', 226),
#  ('longterm', 226),
#  ('crustacea', 226),
#  ('integrative', 226),
#  ('delimitation', 226),
#  ('promote', 225),
#  ('review', 225),
#  ('local', 224),
#  ('strategy', 224),
#  ('tolerance', 223),
#  ('colletotrichum', 222),
#  ('grow', 221),
#  ('symbionts', 221),
#  ('reassortant', 220),
#  ('flow', 220),
#  ('signal', 219),
#  ('full', 219),
#  ('fermentation', 219),
#  ('trypanosoma', 218),
#  ('rhizobium', 218),
#  ('dairy', 218),
#  ('mangrove', 218),
#  ('temperature', 218),
#  ('nitrogen', 217),
#  ('zone', 217),
#  ('liver', 217),
#  ('assess', 216),
#  ('blight', 216),
#  ('syncytial', 216),
#  ('indicate', 216),
#  ('southeast', 216),
#  ('biofilm', 216),
#  ('compound', 214),
#  ('multiplex', 214),
#  ('efficient', 214),
#  ('ecosystem', 214),
#  ('transcribed', 213),
#  ('indigenous', 213),
#  ('mutant', 213),
#  ('genetically', 212),
#  ('experimental', 212),
#  ('coinfection', 212),
#  ('seasonal', 211),
#  ('antifungal', 211),
#  ('assembly', 210),
#  ('snail', 210),
#  ('metabolite', 210),
#  ('fatal', 210),
#  ('laboratory', 210),
#  ('paenibacillus', 209),
#  ('adaptive', 209),
#  ('rtpcr', 209),
#  ('helicobacter', 208),
#  ('oxidase', 208),
#  ('woman', 208),
#  ('synthase', 208),
#  ('urban', 207),
#  ('coxsackievirus', 207),
#  ('barcodes', 207),
#  ('drive', 207),
#  ('vivax', 207),
#  ('regulate', 206),
#  ('generation', 206),
#  ('shift', 206),
#  ('mediate', 205),
#  ('donor', 205),
#  ('bronchitis', 205),
#  ('amazon', 204),
#  ('national', 204),
#  ('extensive', 204),
#  ('phenotype', 204),
#  ('aquatic', 204),
#  ('sand', 203),
#  ('comb', 203),
#  ('maize', 203),
#  ('arbuscular', 202),
#  ('gradient', 202),
#  ('monkey', 202),
#  ('toxin', 202),
#  ('relative', 202),
#  ('diagnostic', 202),
#  ('challenge', 202),
#  ('soybean', 201),
#  ('ecology', 201),
#  ('bean', 201),
#  ('theileria', 201),
#  ('determination', 201),
#  ('long', 200),
#  ('frequency', 200),
#  ('polymorphic', 199),
#  ('intestinal', 199),
#  ('ciliate', 198),
#  ('trait', 198),
#  ('promoter', 198),
#  ('captive', 198),
#  ('moderately', 198),
#  ('iii', 197),
#  ('order', 197),
#  ('recover', 197),
#  ('loss', 197),
#  ('crop', 197),
#  ('invasion', 196),
#  ('burkholderia', 196),
#  ('temporal', 196),
#  ('yunnan', 195),
#  ('microorganism', 195),
#  ('result', 195),
#  ('plastid', 195),
#  ('antiviral', 195),
#  ('combination', 195),
#  ('primate', 194),
#  ('multidrugresistant', 194),
#  ('mottle', 194),
#  ('regulation', 194),
#  ('macaque', 194),
#  ('rabbit', 194),
#  ('discover', 193),
#  ('carp', 193),
#  ('phytophthora', 192),
#  ('mixed', 192),
#  ('serological', 192),
#  ('note', 192),
#  ('old', 191),
#  ('mite', 191),
#  ('enterica', 189),
#  ('city', 189),
#  ('salmon', 189),
#  ('simian', 189),
#  ('spider', 188),
#  ('independent', 188),
#  ('core', 188),
#  ('may', 188),
#  ('broad', 188),
#  ('variable', 187),
#  ('mine', 186),
#  ('capsid', 186),
#  ('archaeal', 186),
#  ('grass', 186),
#  ('organic', 186),
#  ('obtain', 185),
#  ('valley', 185),
#  ('simultaneous', 185),
#  ('enrichment', 185),
#  ('aerobic', 185),
#  ('infant', 185),
#  ('length', 184),
#  ('park', 184),
#  ('clostridium', 184),
#  ('cod', 184),
#  ('symbiont', 183),
#  ('necrosis', 183),
#  ('dwarf', 183),
#  ('phylum', 182),
#  ('light', 182),
#  ('aeromonas', 182),
#  ('country', 181),
#  ('lato', 181),
#  ('epitope', 181),
#  ('zika', 181),
#  ('seed', 180),
#  ('cancer', 179),
#  ('terrestrial', 179),
#  ('mat', 179),
#  ('enterococcus', 178),
#  ('reduction', 178),
#  ('hydrothermal', 178),
#  ('shape', 178),
#  ('hcv', 178),
#  ('nodule', 177),
#  ('contrast', 176),
#  ('flat', 175),
#  ('conserve', 175),
#  ('hantavirus', 174),
#  ('haplotype', 174),
#  ('nextgeneration', 174),
#  ('exhibit', 174),
#  ('crab', 174),
#  ('duodenalis', 174),
#  ('polyomavirus', 173),
#  ('extremely', 173),
#  ('belong', 172),
#  ('serum', 172),
#  ('synthesis', 172),
#  ('astrovirus', 172),
#  ('boar', 171),
#  ('dinoflagellate', 171),
#  ('performance', 171),
#  ('squamata', 171),
#  ('select', 171),
#  ('close', 171),
#  ('metabolic', 171),
#  ('oxidation', 170),
#  ('culex', 170),
#  ('plateau', 170),
#  ('deletion', 170),
#  ('tidal', 170),
#  ('snake', 170),
#  ('present', 170),
#  ('carbon', 169),
#  ('lack', 169),
#  ('wilt', 169),
#  ('sympatric', 169),
#  ('oyster', 169),
#  ('redescription', 169),
#  ('h3n2', 167),
#  ('canis', 167),
#  ('cyprinidae', 167),
#  ('calf', 167),
#  ('alkaline', 167),
#  ('begomovirus', 166),
#  ('lead', 166),
#  ('construction', 166),
#  ('pine', 166),
#  ('temperate', 166),
#  ('import', 166),
#  ('proposal', 166),
#  ('direct', 166),
#  ('positive', 165),
#  ('var', 165),
#  ('rural', 165),
#  ('measles', 165),
#  ('tobacco', 165),
#  ('without', 165),
#  ('enterocytozoon', 165),
#  ('transcriptase', 164),
#  ('reduce', 163),
#  ('insertion', 163),
#  ('ixodidae', 163),
#  ('sewage', 163),
#  ('metabolism', 163),
#  ('efficacy', 163),
#  ('acidic', 162),
#  ('waste', 162),
#  ('wetland', 162),
#  ('antibacterial', 162),
#  ('barcode', 162),
#  ('combine', 162),
#  ('clonal', 161),
#  ('japonica', 161),
#  ('lactic', 161),
#  ('classical', 160),
#  ('paramyxovirus', 160),
#  ('establishment', 160),
#  ('pylorus', 159),
#  ('transmit', 159),
#  ('persistence', 159),
#  ('butterfly', 159),
#  ('transcriptional', 159),
#  ('cucumber', 159),
#  ('ammoniaoxidizing', 159),
#  ('penicillium', 158),
#  ('sinensis', 158),
#  ('confirm', 158),
#  ('body', 158),
#  ('middle', 158),
#  ('phagocytophilum', 158),
#  ('ehrlichia', 158),
#  ('cohort', 158),
#  ('intraspecific', 158),
#  ('termite', 158),
#  ('extreme', 158),
#  ('require', 158),
#  ('reclassification', 157),
#  ('moth', 157),
#  ('situ', 157),
#  ('fecal', 157),
#  ('short', 157),
#  ('hypersaline', 157),
#  ('profiling', 157),
#  ('h9n2', 157),
#  ('cutaneous', 157),
#  ('sugarcane', 156),
#  ('biocontrol', 156),
#  ('trout', 156),
#  ('systematic', 156),
#  ('degrade', 156),
#  ('consortium', 156),
#  ('bay', 156),
#  ('male', 155),
#  ('atypical', 155),
#  ('accumulation', 155),
#  ('stable', 155),
#  ('substitution', 155),
#  ('pleistocene', 154),
#  ('scale', 154),
#  ('near', 154),
#  ('gastropoda', 154),
#  ('apple', 154),
#  ('bieneusi', 154),
#  ('traditional', 154),
#  ('section', 153),
#  ('characterize', 153),
#  ('milk', 153),
#  ('unit', 153),
#  ('ricinus', 153),
#  ('sensitivity', 153),
#  ('campylobacter', 153),
#  ('correlate', 153),
#  ('cave', 153),
#  ('foot', 152),
#  ('rhipicephalus', 152),
#  ('florida', 152),
#  ('feces', 152),
#  ('trematoda', 151),
#  ('identity', 151),
#  ('cyanobacterial', 151),
#  ('horizontal', 151),
#  ('land', 151),
#  ('size', 151),
#  ('represent', 151),
#  ('catfish', 151),
#  ('metal', 151),
#  ('chromosomal', 150),
#  ('turtle', 150),
#  ('health', 150),
#  ('resolve', 150),
#  ('sexual', 150),
#  ('molecule', 149),
#  ('fox', 149),
#  ('basidiomycota', 148),
#  ('pigeon', 148),
#  ('quantification', 148),
#  ('character', 148),
#  ('serovar', 147),
#  ('mortality', 147),
#  ('alternative', 147),
#  ('pepper', 147),
#  ('similar', 147),
#  ('female', 147),
#  ('alga', 147),
#  ('exposure', 146),
#  ('bind', 146),
#  ('trichoderma', 146),
#  ('mildew', 146),
#  ('subspecies', 146),
#  ('contribution', 146),
#  ('vein', 145),
#  ('biosynthetic', 145),
#  ('highthroughput', 145),
#  ('niche', 145),
#  ('enteric', 145),
#  ('intermediate', 144),
#  ('methane', 144),
#  ('sarcocystis', 144),
#  ('focus', 144),
#  ('network', 144),
#  ('methicillinresistant', 144),
#  ('amblyomma', 144),
#  ('asymptomatic', 144),
#  ('isothermal', 144),
#  ('subfamily', 143),
#  ('lichen', 143),
#  ('decapoda', 143),
#  ('arabidopsis', 143),
#  ('subgenus', 143),
#  ('comprehensive', 143),
#  ('reassortment', 143),
#  ('virological', 143),
#  ('probe', 143),
#  ('hbv', 143),
#  ('symbiosis', 143),
#  ('saline', 143),
#  ('recently', 142),
#  ('apicomplexa', 142),
#  ('mammalian', 142),
#  ('ascomycota', 142),
#  ('failure', 142),
#  ('flower', 141),
#  ('isolated', 141),
#  ('season', 141),
#  ('late', 141),
#  ('env', 141),
#  ('oral', 141),
#  ('cyanobacterium', 141),
#  ('leukemia', 141),
#  ('various', 141),
#  ('reef', 141),
#  ('circulating', 141),
#  ('brain', 141),
#  ('technique', 141),
#  ('subtilis', 140),
#  ...]

# %%
len(list(words_counter.keys()))
# Out:
# 94792

# %%
bottomfiltered_words_counter = Counter({key: value for key, value in words_counter.items() if value > 2})

# %%
len(list(bottomfiltered_words_counter.keys()))
# Out:
# 24918

# %%
words_to_keep = list(bottomfiltered_words_counter.keys())

# %%
titles_cleaned = []
titles_cleaned_stopwords_cut = []
#nr = 1
for title in titles_cleaned_stopwords:
    cleaned_title = ''
    for word in title.split(): 
        if word in words_to_keep:
            if cleaned_title == '': 
                cleaned_title = word
            else: 
                cleaned_title = cleaned_title + ' ' + word
    title_length = len(cleaned_title.split())

    titles_cleaned.append(cleaned_title)
    titles_cleaned_stopwords_cut.append(title)
    
    #if title_length <= 2: 
    #    print('smallllll')
    #    print(title)
    #    print(cleaned_title)
    #elif title_length >= 26: 
    #    print('largeee')
    #    print(title)
    #    print(cleaned_title)
    #nr = nr +1
    #print(nr)
    #if nr == 4: 
    #    break
    #if til

# %%
len(titles_cleaned)
# Out:
# 99179

# %%
titles_cleaned_nodup = list(set(titles_cleaned))
len(titles_cleaned_nodup)
# Out:
# 98859

# %%
len(titles_nodup)
# Out:
# 99179

# %%
ori_cle_title_dict = dict(zip(titles_nodup, titles_cleaned))

# %%
df_scholarly['title_clean'] = df_scholarly['title'].map(ori_cle_title_dict)

# %%
df_scholarly_clean = df_scholarly[df_scholarly['title_clean']!= '']

# %%
df_scholarly_clean.to_csv(path+R'processed_data\scholarly_cleaned.csv')

# %% [markdown]
# ### 3. Create TF-IDF weights for filtering out words that occur similary often/little across all documents

# %%
df_scholarly_clean = pd.read_csv(path+R'processed_data\scholarly_cleaned.csv', index_col = 0)
# Out:
# <ipython-input-3-c6ad7486ca85>:1: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_scholarly_clean = pd.read_csv(path+R'processed_data\scholarly_cleaned.csv', index_col = 0)

# %%
df_scholarly_clean_nd = df_scholarly_clean[['id_select','title_clean']].drop_duplicates() #cannot just drop duplicate titles because some of the duplicats are a result of the cleaning rather than actual duplicates

# %%
titles_cleaned_nodup = df_scholarly_clean_nd['title_clean'].tolist()

# %%
# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer() #max_df=0.95, min_df=4

# Fit the TF-IDF model and transform the titles into a sparse TF-IDF matrix
tfidf_matrix = vectorizer.fit_transform(titles_cleaned_nodup)

# Get the feature names (words) and their corresponding indices in the TF-IDF matrix
feature_names = vectorizer.get_feature_names_out()

# Step 2: Prepare lists to store log TF-IDF and log rank for averaging
max_rank = 1000  # Set a max rank cutoff to avoid extreme outliers; can be adjusted
log_tfidf_sums = np.zeros(max_rank)
rank_counts = np.zeros(max_rank)

# For each title (row in the tfidf_matrix), compute log TF-IDF vs log rank
for i in range(tfidf_matrix.shape[0]):
    # Get the non-zero indices and corresponding TF-IDF scores for the current title
    row = tfidf_matrix.getrow(i)
    non_zero_indices = row.indices
    non_zero_scores = row.data
    
    title_word_scores = pd.DataFrame({
        'word': feature_names[non_zero_indices],
        'tfidf_score': non_zero_scores
    })
    
    # Sort the words by TF-IDF score in descending order
    title_word_scores_sorted = title_word_scores.sort_values(by='tfidf_score', ascending=False)
    
    # Assign ranks
    title_word_scores_sorted['rank'] = np.arange(1, len(title_word_scores_sorted) + 1)
    
    # Remove any zero TF-IDF scores
    title_word_scores_sorted = title_word_scores_sorted[title_word_scores_sorted['tfidf_score'] > 0]
    
    # Compute the logarithms of TF-IDF scores and ranks
    log_tfidf = np.log(title_word_scores_sorted['tfidf_score'])
    log_rank = np.log(title_word_scores_sorted['rank'])
    
    # Limit to max_rank to avoid very high ranks (optional)
    for j in range(min(len(log_tfidf), max_rank)):
        log_tfidf_sums[j] += log_tfidf.iloc[j]
        rank_counts[j] += 1

# Step 3: Calculate the average log TF-IDF scores for each rank
average_log_tfidf = log_tfidf_sums / rank_counts

# Generate a log rank axis for plotting (from 1 to max_rank)
log_rank_axis = np.log(np.arange(1, max_rank + 1))

# Step 4: Plot the average log TF-IDF scores vs log rank
plt.figure(figsize=(10, 6))
plt.plot(log_rank_axis, average_log_tfidf, label='Average across Titles')

# Add a threshold line (at y = -2.1 in this case)
plt.axhline(y=-2.15, color='red', linestyle='--', label='Threshold: y = -2.15')

plt.title('Average Log of TF-IDF Scores vs Log of Ranks')
plt.xlabel('Log Transformed Word Rank')
plt.ylabel('Log Transformed TF-IDF Score')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-30-e7cb1efb3a9c>:46: RuntimeWarning: invalid value encountered in divide
#   average_log_tfidf = log_tfidf_sums / rank_counts

# %%
words_below_threshold = []

# Iterate over each title's TF-IDF scores to find words with log(TF-IDF) < -2.15
for i in range(tfidf_matrix.shape[0]):
    # Get the non-zero indices and corresponding TF-IDF scores for the current title
    row = tfidf_matrix.getrow(i)
    non_zero_indices = row.indices
    non_zero_scores = row.data
    
    title_word_scores = pd.DataFrame({
        'word': feature_names[non_zero_indices],
        'tfidf_score': non_zero_scores
    })
    
    # Compute the logarithm of the TF-IDF scores
    title_word_scores['log_tfidf'] = np.log(title_word_scores['tfidf_score'])
    
    # Filter words with log-transformed TF-IDF score below -2.15
    filtered_words = title_word_scores[title_word_scores['log_tfidf'] < -2.15]
    
    # Append the filtered words to the result list
    words_below_threshold.extend(filtered_words['word'].tolist())

# Step 2: Remove duplicates (since the same word might appear across different titles)
unique_words_below_threshold = list(set(words_below_threshold))

print(f"Words with log-transformed TF-IDF scores below -2.15: {len(unique_words_below_threshold)}")
print(unique_words_below_threshold)

pd.DataFrame(unique_words_below_threshold, columns=['word']).to_csv(path+R'processed_data\words_below_log_tfidf_-2.15.csv', index=False)
# Out:
# Words with log-transformed TF-IDF scores below -2.15: 166
# ['relationship', 'high', 'iii', 'surface', 'domestic', 'reveal', 'human', 'deposit', 'evidence', 'genus', 'variant', 'association', 'anaerobic', 'staphylococcus', 'cdna', 'proposal', 'late', 'yeast', 'molecular', 'plant', 'sediment', 'photorhabdus', 'within', 'family', 'polyphasic', 'resistance', 'amplification', 'thermophilic', 'microsatellite', 'pathogen', 'conserve', 'gene', 'diversity', 'lineage', 'gen', 'among', 'implication', 'halomonas', 'viridans', 'culture', 'wastewater', 'variation', 'approach', 'acid', 'morphological', 'transfer', 'identification', 'report', 'cellulosedecomposing', 'central', 'soil', 'mitochondrial', 'isolate', 'nov', 'yellow', 'candida', 'use', 'represent', 'complete', 'emend', 'expression', 'vietnamensis', 'bacteria', 'group', 'moderately', 'reichenbachii', 'sea', 'base', 'taxon', 'bacterium', 'lake', 'coastal', 'natural', 'xenorhabdus', 'rna', 'novel', 'isolates', 'infection', 'study', 'isolation', 'nuclear', 'taxonomy', 'infect', 'development', 'cattle', 'dsm', 'virulence', 'type', 'potential', 'fish', 'wild', 'freshwater', 'marine', 'proteincoding', 'synonym', 'region', 'strain', 'characterization', 'classification', 'source', 'dna', 'island', 'detection', 'bacterial', 'identify', 'virus', 'suis', 'bt', 'cell', 'genome', 'host', 'fungi', 'marker', 'specie', 'evolution', 'population', 'cause', 'origin', 'avian', 'clade', 'common', 'arenae', 'associate', 'rrna', 'complex', 'heterogeneity', 'phylogeny', 'water', 'universally', 'assay', 'new', 'assignment', 'genotype', 'member', 'phylogenetic', 'hainanensis', 'comparative', 'description', 'different', 'reclassification', 'genetic', 'clinical', 'mutation', 'community', 'prevalence', 'patient', 'disease', 'pcr', 'taxonomic', 'sequence', 'coli', 'emendation', 'hybridization', 'fam', 'genomic', 'analysis', 'transmission', 'newly', 'cryptic', 'cloning', 'include', 'comb', 'lead', 'orientale', 'pathogenic', 'protein']

# %%
#filter out the most generic words
titles_clean_tfidf = []
for title in titles_cleaned_nodup: 
    title_clean_tfidf = ''
    for word in title.split(): 
        if word not in unique_words_below_threshold: 
            if title_clean_tfidf == '':
                title_clean_tfidf= word 
            else: 
                title_clean_tfidf = title_clean_tfidf + ' ' + word
    titles_clean_tfidf.append(title_clean_tfidf)
    
clean_tfidf_dict = dict(zip(titles_cleaned_nodup, titles_clean_tfidf))

# %%
df_scholarly_clean['title_clean_tfidf'] = df_scholarly_clean['title_clean'].map(clean_tfidf_dict)

# %%
df_scholarly_clean_nodup[['id_select','titles_clean']].drop_duplicates()
# Out:
# <ipython-input-40-4fa3782b84bb>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_scholarly_clean_nd[df_scholarly_clean['title_clean'] != '']
#                              id_select  \
# 0                           32373149.0
# 4                           34227832.0
# 9                           19763271.0
# 19                          29324085.0
# 23                          30727098.0
# ...                                ...
# 9065  10.1111/j.1365-3059.2009.02058.x
# 9070     10.1016/j.soilbio.2008.04.022
# 9076     10.1016/j.soilbio.2006.03.003
# 9083      10.1016/j.apsoil.2010.01.002
# 9087                 10.1111/epp.12443
#
#                                             title_clean
# 0     evolution expression reproductive transition r...
# 4                      report grapevine virus grapevine
# 9     limited neutralize antibody specificity drive ...
# 19    hyperparasitism avian ectoparasitic fly mite c...
# 23    report ricini cause gray mold disease acalypha...
# ...                                                 ...
# 9065  report association candidatus phytoplasma aste...
# 9070  combined effect bioaugmentation atrazine degra...
# 9076  diversity antagonistic potential pseudomonas a...
# 9083  rhizobacteria effect growth pigeon pea cajanus...
# 9087  record new location tropical root knot nematod...
#
# [99167 rows x 2 columns]

# %%
df_scholarly_clean_tfidf_nd= df_scholarly_clean[['id_select','title_clean_tfidf']].drop_duplicates()

# %%
#how many '' did I create in via the tf idfs?
df_scholarly_clean_tfidf_nd[df_scholarly_clean_tfidf_nd['title_clean_tfidf'] != '']
# Out:
#                              id_select  \
# 0                           32373149.0
# 4                           34227832.0
# 9                           19763271.0
# 19                          29324085.0
# 23                          30727098.0
# ...                                ...
# 9065  10.1111/j.1365-3059.2009.02058.x
# 9070     10.1016/j.soilbio.2008.04.022
# 9076     10.1016/j.soilbio.2006.03.003
# 9083      10.1016/j.apsoil.2010.01.002
# 9087                 10.1111/epp.12443
#
#                                       title_clean_tfidf
# 0     reproductive transition regulatory emphasis se...
# 4                                   grapevine grapevine
# 9     limited neutralize antibody specificity drive ...
# 19    hyperparasitism ectoparasitic fly mite cf bore...
# 23                  ricini gray mold acalypha australis
# ...                                                 ...
# 9065  candidatus phytoplasma asteris 16sri little le...
# 9070  combined effect bioaugmentation atrazine degra...
# 9076  antagonistic pseudomonas rhizosphere maize gro...
# 9083  rhizobacteria effect growth pigeon pea cajanus...
# 9087  record location tropical root knot nematode me...
#
# [99003 rows x 2 columns]

# %%
df_scholarly_clean[df_scholarly_clean['title_clean_tfidf'] != ''].to_csv(path+R'processed_data\scholarly_cleaned_tfidf.csv')

# %%
#create the word-pub_id dict so I can later on remerge
from collections import defaultdict

word_id_dict = defaultdict(set)  # Store sets of IDs for each word
for title in list(df_scholarly_clean_tfidf_nd['title_clean_tfidf']):
    words = title.split()
    for word in words:
        word_id_dict[word].add(list(df_scholarly_clean_tfidf_nd['id_select'][df_scholarly_clean_tfidf_nd['title_clean_tfidf'] == title])[0])  # Add ID to the set for the word

# %%
# Convert sets to lists to make them JSON serializable
word_id_dict_serializable = {word: list(ids) for word, ids in word_id_dict.items()}

# Save to a JSON file
with open(path+R'processed_data\word_id_dict_+2_tfidf.json', 'w') as json_file:
    json.dump(word_id_dict_serializable, json_file, indent=4)
