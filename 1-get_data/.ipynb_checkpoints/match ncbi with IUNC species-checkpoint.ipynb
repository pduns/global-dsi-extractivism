# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Load data

# %%
df_iucn = pd.read_csv('2024-12-11_IUCN_global_assessment_all_categories_simple_summary.csv')
df_wildsi_and_ncbi = pd.read_csv('../../data/processed_data/2024-08-28_df_wildsi_with_ncbi_lineage.csv')

# %% [markdown]
# ### Select NCBI species for analysis - categories assessed by IUCN

# %%
df_wildsi_and_ncbi_only_species = df_wildsi_and_ncbi[df_wildsi_and_ncbi['Rank'] == 'SPECIES']

# %%
#df_wildsi_and_ncbi_only_species_with_iucn_categories = df_wildsi_and_ncbi_only_species[(df_wildsi_and_ncbi_only_species['CODE'] == 'PLN')]
df_wildsi_and_ncbi_only_species_with_iucn_categories = df_wildsi_and_ncbi_only_species[(df_wildsi_and_ncbi_only_species['CODE'] == 'PLN') | (df_wildsi_and_ncbi_only_species['Kingdom name'].isin(['Metazoa', 'Fungi']))]

# %% [markdown]
# ### Select IUCN species

# %%
category_mapping = {  
    'Critically Endangered': 'Threatened',  
    'Endangered': 'Threatened',  
    'Vulnerable': 'Threatened',  
    'Near Threatened': 'Lower Risk',  
    'Least Concern': 'Lower Risk',  
    'Data Deficient': 'Lower Risk',
    'Lower Risk/least concern': 'Lower Risk',
    'Lower Risk/near threatened': 'Lower Risk',
    'Lower Risk/conservation dependent': 'Lower Risk',
    'Extinct': 'Extinct',  
    'Extinct in the Wild': 'Extinct',
    'Data Deficient': 'Data Deficient',
    'Not assessed': 'Not assessed'
}

# %%
df_iucn_selected = df_iucn[['internalTaxonId', 'scientificName', 'populationTrend', 'redlistCategory']]

# %%
df_iucn_selected.columns = ['internalTaxonId', 'Species name', 'populationTrend', 'redlistCategory']

# %%
df_ncbi_lineage_with_iucn = pd.merge(df_wildsi_and_ncbi_only_species_with_iucn_categories, df_iucn_selected, on='Species name', how='left')

# %%
df_ncbi_lineage_with_iucn['redlistCategory'].fillna('Not assessed', inplace=True)

# %%
df_ncbi_lineage_with_iucn_assessed = df_ncbi_lineage_with_iucn
df_ncbi_lineage_with_iucn_assessed = df_ncbi_lineage_with_iucn[df_ncbi_lineage_with_iucn['redlistCategory'] != 'Not assessed']

# %%
df_ncbi_lineage_with_iucn_assessed['Aggregated_Category'] = df_ncbi_lineage_with_iucn_assessed['redlistCategory'].map(category_mapping)
# Out:
# <ipython-input-172-ea0ecc1c00ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ncbi_lineage_with_iucn_assessed['Aggregated_Category'] = df_ncbi_lineage_with_iucn_assessed['redlistCategory'].map(category_mapping)

# %%
df_ncbi_lineage_with_iucn_assessed['Phylum name'].value_counts()
# Out:
# Phylum name
# Chordata         32635
# Streptophyta     21790
# Arthropoda        4234
# Mollusca          2218
# Cnidaria           439
# Basidiomycota      352
# Echinodermata       90
# Ascomycota          89
# Annelida            57
# Rhodophyta           7
# Onychophora          1
# Name: count, dtype: int64

# %%
df_ncbi_lineage_with_iucn['redlistCategory'].value_counts()
# Out:
# redlistCategory
# Not assessed                         968208
# Least Concern                         42340
# Endangered                             5042
# Vulnerable                             5009
# Data Deficient                         3538
# Near Threatened                        3345
# Critically Endangered                  2296
# Lower Risk/near threatened              144
# Extinct                                  88
# Lower Risk/least concern                 51
# Extinct in the Wild                      37
# Lower Risk/conservation dependent        24
# Name: count, dtype: int64

# %%
# Count the occurrences of each category  
category_counts = df_ncbi_lineage_with_iucn_assessed['Aggregated_Category'].value_counts()  

# Calculate percentages  
total_counts = category_counts.sum()  
percentages = (category_counts / total_counts) * 100  

# Create a bar plot  
plt.figure(figsize=(10, 6))  
ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')  
plt.title('Distribution of Red List Categories')  
plt.xlabel('Red List Category')  
plt.ylabel('Count')  
plt.xticks(rotation=45)  

# Display percentages on the bars  
for p in ax.patches:  
    ax.annotate(f'{p.get_height()} ({percentages[category_counts.index[int(p.get_x() + p.get_width() / 2)]]:.1f}%)',   
                (p.get_x() + p.get_width() / 2., p.get_height()),   
                ha='center', va='bottom', fontsize=10)  

plt.show()
# Out:
# <ipython-input-175-56dd210b89e0>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
df_ncbi_lineage_with_iucn_assessed
# Out:
#          Unnamed: 0    Taxid CODE                ORGANISM     Rank  \
# 2                 4    36312  VRT     Hynobius retardatus  SPECIES
# 3                 6   184236  VRT  Crocodylus mindorensis  SPECIES
# 7                13    28930  PLN         Fagus sylvatica  SPECIES
# 13               22   240206  VRT    Pterocles gutturalis  SPECIES
# 14               23    37682  PLN       Aegilops tauschii  SPECIES
# ...             ...      ...  ...                     ...      ...
# 1030004     1532592  1141219  VRT     Batrachoseps luciae  SPECIES
# 1030014     1532609  3027289  PLN         Mimosa sobralii  SPECIES
# 1030016     1532613  1208023  VRT      Cnemaspis podihuna  SPECIES
# 1030036     1532642  1450153  VRT         Liolaemus sagei  SPECIES
# 1030041     1532650  2528955  PLN      Eremophila youngii  SPECIES
#
#                Group name Superkingdom name   Kingdom name   Phylum name  \
# 2             salamanders         Eukaryota        Metazoa      Chordata
# 3              crocodiles         Eukaryota        Metazoa      Chordata
# 7                eudicots         Eukaryota  Viridiplantae  Streptophyta
# 13                  birds         Eukaryota        Metazoa      Chordata
# 14               monocots         Eukaryota  Viridiplantae  Streptophyta
# ...                   ...               ...            ...           ...
# 1030004       salamanders         Eukaryota        Metazoa      Chordata
# 1030014          eudicots         Eukaryota  Viridiplantae  Streptophyta
# 1030016  lizards & snakes         Eukaryota        Metazoa      Chordata
# 1030036  lizards & snakes         Eukaryota        Metazoa      Chordata
# 1030041          eudicots         Eukaryota  Viridiplantae  Streptophyta
#
#             Class name      Order name       Family name    Genus name  \
# 2             Amphibia         Caudata        Hynobiidae      Hynobius
# 3                  NaN      Crocodylia      Crocodylidae    Crocodylus
# 7        Magnoliopsida         Fagales          Fagaceae         Fagus
# 13                Aves  Pterocliformes       Pteroclidae     Pterocles
# 14       Magnoliopsida          Poales           Poaceae      Aegilops
# ...                ...             ...               ...           ...
# 1030004       Amphibia         Caudata    Plethodontidae  Batrachoseps
# 1030014  Magnoliopsida         Fabales          Fabaceae        Mimosa
# 1030016   Lepidosauria        Squamata        Gekkonidae     Cnemaspis
# 1030036   Lepidosauria        Squamata         Iguanidae     Liolaemus
# 1030041  Magnoliopsida        Lamiales  Scrophulariaceae    Eremophila
#
#                    Species name  internalTaxonId populationTrend  \
# 2           Hynobius retardatus          59101.0      Decreasing
# 3        Crocodylus mindorensis           5672.0      Decreasing
# 7               Fagus sylvatica       62004722.0         Unknown
# 13         Pterocles gutturalis       22692998.0      Decreasing
# 14            Aegilops tauschii         172086.0          Stable
# ...                         ...              ...             ...
# 1030004     Batrachoseps luciae          59127.0          Stable
# 1030014         Mimosa sobralii      177829529.0      Decreasing
# 1030016      Cnemaspis podihuna         178662.0      Decreasing
# 1030036         Liolaemus sagei       56149101.0          Stable
# 1030041      Eremophila youngii      198149708.0          Stable
#
#                redlistCategory Aggregated_Category
# 2                Least Concern          Lower Risk
# 3        Critically Endangered          Threatened
# 7                Least Concern          Lower Risk
# 13               Least Concern          Lower Risk
# 14               Least Concern          Lower Risk
# ...                        ...                 ...
# 1030004          Least Concern          Lower Risk
# 1030014             Endangered          Threatened
# 1030016             Vulnerable          Threatened
# 1030036          Least Concern          Lower Risk
# 1030041          Least Concern          Lower Risk
#
# [61914 rows x 18 columns]

# %%
# Step 1: Prepare the data for the stacked bar plot  
# Count occurrences of each Aggregated_Category within each Group name  
grouped_data = df_ncbi_lineage_with_iucn_assessed.groupby(['Phylum name', 'Aggregated_Category']).size().unstack(fill_value=0).sort_values(by='Lower Risk', ascending=False) 

# Step 2: Create the stacked bar plot  
grouped_data.plot(kind='bar', stacked=True, figsize=(20, 12))  

# Step 3: Customize the plot  
plt.title('Stacked Bar Plot of Group Name by Aggregated Category')  
plt.xlabel('Group Name')  
plt.ylabel('Number of Species')  
plt.legend(title='Aggregated Category')  
plt.xticks(rotation=45)  
plt.tight_layout()  # Adjust layout to make room for the labels  

# Step 4: Show the plot  
plt.show()

# %%
# Count occurrences of each Aggregated_Category within each Group name  
grouped_data = df_ncbi_lineage_with_iucn_assessed.groupby(['Group name', 'Aggregated_Category']).size().unstack(fill_value=0).sort_values(by='Lower Risk', ascending=False)  

# Step 2: Calculate the total number of species for each group  
total_species = grouped_data.sum(axis=1)  

# Step 3: Create the stacked bar plot  
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(20, 12), alpha=0.7)  

# Step 4: Overlay the percentages for the "Threatened" category  
if 'Threatened' in grouped_data.columns:  
    for i in range(len(grouped_data)):  
        threatened_value = grouped_data.iloc[i]['Threatened']  
        if threatened_value > 0:  # Only display percentage if there is a value  
            percentage = (threatened_value / total_species[i]) * 100  
            ax.text(i, threatened_value + 1, f'{percentage:.1f}%', ha='center', va='bottom')  

# Step 5: Customize the plot  
plt.title('Stacked Bar Plot of Group Name by Aggregated Category')  
plt.xlabel('Group Name')  
plt.ylabel('Number of Species')  
plt.legend(title='Aggregated Category')  
plt.xticks(rotation=45)  
plt.tight_layout()  # Adjust layout to make room for the labels  

# Step 6: Show the plot  
plt.show()

# %% [markdown]
# ### Selecting terrestrial species

# %%
terrestrial_phyla = ['Chordata', 'Arthropoda', 'Onychophora']
Chordata_ter_groups = [
    'birds',  
    'frogs & toads',  
    'lizards & snakes',  
    'snakes',  
    'rodents',  
    'bats',  
    'salamanders',  
    'primates',  
    'insectivores',  
    'marsupials',   
    'carnivores',  
    'hawks & eagles',  
    'placentals',   
    'rabbits & hares',  
    'caecilians',  
    'crocodiles',  
    'odd-toed ungulates',  
    'vertebrates',
    'monotremes',  
] 

Arthropoda_ter_groups = [  
    'damselflies',  
    'dragonflies & damselflies',  
    'butterflies',  
    'beetles',  
    'bees',  
    'crickets',  
    'flies',  
    'spiders',  
    'grasshoppers',  
    'moths',  
    'ants',  
    'millipedes',  
    'walking sticks',  
    'mantids',  
    'bugs',   
    'mites & ticks',  
    'insects',  
    'termites',  
    'roaches',  
    'stoneflies',  
    'psyllids',  
    'mayflies',  
    'caddisflies',  
    'springtails'  
]

Onychophora_ter_groups = ['velvet worms']

# %%
phylum_groups_terr = {  
    'Arthropoda': Arthropoda_ter_groups,
    'Chordata': Chordata_ter_groups,
    'Onychophora': Onychophora_ter_groups, 
}  

# Filter the DataFrame based on phylum and group names  
terrestrial_DSI = df_ncbi_lineage_with_iucn_assessed[  
    df_ncbi_lineage_with_iucn_assessed['Phylum name'].isin(terrestrial_phyla) &   
    df_ncbi_lineage_with_iucn_assessed['Group name'].isin(  
        [group for groups in phylum_groups_terr.values() for group in groups]  
    )  
]

# %%
#all_terrestrial_species = pd.concat([terrestrial_DSI, df_ncbi_lineage_with_iucn_assessed_plants, df_ncbi_lineage_with_iucn_assessed_fungi])

# %% [markdown]
# ### Terrestrial DSI

# %%
# Count the occurrences of each category  
category_counts = terrestrial_DSI['Aggregated_Category'].value_counts()  

# Calculate percentages  
total_counts = category_counts.sum()  
percentages = (category_counts / total_counts) * 100  

# Create a bar plot  
plt.figure(figsize=(10, 6))  
ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')  
plt.title('Distribution of Red List Categories')  
plt.xlabel('Red List Category')  
plt.ylabel('Count')  
plt.xticks(rotation=45)  

# Display percentages on the bars  
for p in ax.patches:  
    ax.annotate(f'{p.get_height()} ({percentages[category_counts.index[int(p.get_x() + p.get_width() / 2)]]:.1f}%)',   
                (p.get_x() + p.get_width() / 2., p.get_height()),   
                ha='center', va='bottom', fontsize=10)  

plt.show()
# Out:
# <ipython-input-182-bd090789f02d>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
terrestrial_DSI['Group name'].value_counts()
# Out:
# Group name
# birds                        5465
# frogs & toads                4255
# lizards & snakes             3185
# snakes                       1565
# rodents                      1420
# damselflies                  1017
# bats                          808
# dragonflies & damselflies     677
# butterflies                   536
# salamanders                   496
# primates                      316
# insectivores                  274
# marsupials                    251
# beetles                       244
# carnivores                    213
# hawks & eagles                193
# bees                          169
# crickets                      137
# flies                         133
# placentals                    121
# spiders                       100
# grasshoppers                   95
# moths                          74
# rabbits & hares                67
# caecilians                     57
# ants                           41
# millipedes                     24
# crocodiles                     13
# walking sticks                 13
# odd-toed ungulates             13
# vertebrates                    10
# mantids                         7
# bugs                            5
# mites & ticks                   4
# insects                         3
# monotremes                      2
# termites                        2
# caddisflies                     1
# psyllids                        1
# mayflies                        1
# stoneflies                      1
# roaches                         1
# velvet worms                    1
# springtails                     1
# Name: count, dtype: int64

# %%
# Count occurrences of each Aggregated_Category within each Group name  
grouped_data = terrestrial_DSI.groupby(['Group name', 'Aggregated_Category']).size().unstack(fill_value=0).sort_values(by='Lower Risk', ascending=False)  

# Step 2: Calculate the total number of species for each group  
total_species = grouped_data.sum(axis=1)  

# Step 3: Create the stacked bar plot  
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(20, 12), alpha=0.7)  

# Step 4: Overlay the percentages for the "Threatened" category  
if 'Threatened' in grouped_data.columns:  
    for i in range(len(grouped_data)):  
        threatened_value = grouped_data.iloc[i]['Threatened']  
        if threatened_value > 0:  # Only display percentage if there is a value  
            percentage = (threatened_value / total_species[i]) * 100  
            ax.text(i, threatened_value + 1, f'{percentage:.1f}%', ha='center', va='bottom')  

# Step 5: Customize the plot  
plt.title('Stacked Bar Plot of Group Name by Aggregated Category')  
plt.xlabel('Group Name')  
plt.ylabel('Number of Species')  
plt.legend(title='Aggregated Category')  
plt.xticks(rotation=45)  
plt.tight_layout()  # Adjust layout to make room for the labels  

# Step 6: Show the plot  
plt.show()

# %%
terrestrial_DSI['Aggregated_Category_Species'] = 'Other terrestrial species'
# Out:
# <ipython-input-185-0003ece7feb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   terrestrial_DSI['Aggregated_Category_Species'] = 'Other terrestrial species'

# %% [markdown]
# ### Selecting marine species

# %%
marine_phyla = ['Arthropoda', 'Mollusca', 'Cnidaria', 'Annelida', 'Echinodermata', 'Chordata']
Arthropoda_groups = ['crustaceans', 'amphipods', 'isopods', 'horseshoe crabs']
Mollusca_groups = ['gastropods', 'bivalves', 'cephalopods']
Cnidaria_groups = ['stony corals', 'hydrozoans', 'blue corals', 'soft corals', 'sea pens', 'sea anemones', 'mat anemones']
Annelida_groups = ['segmented worms']
Echinodermata_groups = ['sea cucumbers', 'starfish', 'sea urchins']
Chordata_groups = ['bony fishes', 'sharks & rays', 'turtles', 'whales & dolphins', 'chimaeras', 'lampreys', 'hagfishes', 'even-toed ungulates & whales', 'coelacanths', 'lungfishes']

#df_ncbi_lineage_with_iucn_assessed_arthropoda['Group name'].value_counts()

# %%
#df_ncbi_lineage_with_iucn_assessed_metazoa = df_ncbi_lineage_with_iucn_assessed[df_ncbi_lineage_with_iucn_assessed['Phylum name'] == 'Onychophora']
#df_ncbi_lineage_with_iucn_assessed_metazoa['Group name'].value_counts()

# %%
phylum_groups = {  
    'Arthropoda': Arthropoda_groups,  
    'Mollusca': Mollusca_groups,  
    'Cnidaria': Cnidaria_groups,  
    'Annelida': Annelida_groups,  
    'Echinodermata': Echinodermata_groups,  
    'Chordata': Chordata_groups  
}  

# Filter the DataFrame based on phylum and group names  
marine_DSI = df_ncbi_lineage_with_iucn_assessed[  
    df_ncbi_lineage_with_iucn_assessed['Phylum name'].isin(marine_phyla) &   
    df_ncbi_lineage_with_iucn_assessed['Group name'].isin(  
        [group for groups in phylum_groups.values() for group in groups]  
    )  
]

# %% [markdown]
# ### Marine DSI

# %%
# Count the occurrences of each category  
category_counts = marine_DSI['Aggregated_Category'].value_counts()  

# Calculate percentages  
total_counts = category_counts.sum()  
percentages = (category_counts / total_counts) * 100  

# Create a bar plot  
plt.figure(figsize=(10, 6))  
ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')  
plt.title('Distribution of Red List Categories')  
plt.xlabel('Red List Category')  
plt.ylabel('Count')  
plt.xticks(rotation=45)  

# Display percentages on the bars  
for p in ax.patches:  
    ax.annotate(f'{p.get_height()} ({percentages[category_counts.index[int(p.get_x() + p.get_width() / 2)]]:.1f}%)',   
                (p.get_x() + p.get_width() / 2., p.get_height()),   
                ha='center', va='bottom', fontsize=10)  

plt.show()
# Out:
# <ipython-input-189-dbf3ba3df749>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
marine_DSI['Group name'].value_counts()
# Out:
# Group name
# bony fishes                     12574
# gastropods                       1591
# crustaceans                       916
# sharks & rays                     757
# stony corals                      412
# bivalves                          327
# cephalopods                       300
# turtles                           216
# even-toed ungulates & whales      179
# sea cucumbers                      88
# whales & dolphins                  84
# segmented worms                    57
# chimaeras                          37
# lampreys                           33
# hagfishes                          24
# amphipods                          22
# hydrozoans                          9
# blue corals                         6
# sea pens                            5
# lungfishes                          5
# isopods                             5
# soft corals                         5
# horseshoe crabs                     4
# coelacanths                         2
# starfish                            1
# sea anemones                        1
# sea urchins                         1
# mat anemones                        1
# Name: count, dtype: int64

# %%
# Count occurrences of each Aggregated_Category within each Group name  
grouped_data = marine_DSI.groupby(['Group name', 'Aggregated_Category']).size().unstack(fill_value=0).sort_values(by='Lower Risk', ascending=False)  

# Step 2: Calculate the total number of species for each group  
total_species = grouped_data.sum(axis=1)  

# Step 3: Create the stacked bar plot  
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(20, 12), alpha=0.7)  

# Step 4: Overlay the percentages for the "Threatened" category  
if 'Threatened' in grouped_data.columns:  
    for i in range(len(grouped_data)):  
        threatened_value = grouped_data.iloc[i]['Threatened']  
        if threatened_value > 0:  # Only display percentage if there is a value  
            percentage = (threatened_value / total_species[i]) * 100  
            ax.text(i, threatened_value + 1, f'{percentage:.1f}%', ha='center', va='bottom')  

# Step 5: Customize the plot  
plt.title('Stacked Bar Plot of Group Name by Aggregated Category')  
plt.xlabel('Group Name')  
plt.ylabel('Number of Species')  
plt.legend(title='Aggregated Category')  
plt.xticks(rotation=45)  
plt.tight_layout()  # Adjust layout to make room for the labels  

# Step 6: Show the plot  
plt.show()

# %%
marine_DSI['Aggregated_Category_Species'] = 'Marine species'
# Out:
# <ipython-input-192-7ef3bfab7511>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marine_DSI['Aggregated_Category_Species'] = 'Marine species'

# %% [markdown]
# ### Plants DSI

# %%
plants_DSI = df_ncbi_lineage_with_iucn_assessed[df_ncbi_lineage_with_iucn_assessed['CODE'] == 'PLN']

# %%
# Count the occurrences of each category  
category_counts = plants_DSI['Aggregated_Category'].value_counts()  

# Calculate percentages  
total_counts = category_counts.sum()  
percentages = (category_counts / total_counts) * 100  

# Create a bar plot  
plt.figure(figsize=(10, 6))  
ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')  
plt.title('Distribution of Red List Categories')  
plt.xlabel('Red List Category')  
plt.ylabel('Count')  
plt.xticks(rotation=45)  

# Display percentages on the bars  
for p in ax.patches:  
    ax.annotate(f'{p.get_height()} ({percentages[category_counts.index[int(p.get_x() + p.get_width() / 2)]]:.1f}%)',   
                (p.get_x() + p.get_width() / 2., p.get_height()),   
                ha='center', va='bottom', fontsize=10)  

plt.show()
# Out:
# <ipython-input-194-a2d63653cc24>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
plants_DSI['Group name'].value_counts()
# Out:
# Group name
# eudicots            15589
# monocots             2974
# flowering plants     2121
# seed plants           672
# ferns                 261
# mosses                 81
# liverworts             45
# club-mosses            30
# horsetails              8
# green plants            7
# red algae               7
# brown algae             2
# hornworts               2
# Name: count, dtype: int64

# %%
# Count occurrences of each Aggregated_Category within each Group name  
grouped_data = plants_DSI.groupby(['Group name', 'Aggregated_Category']).size().unstack(fill_value=0).sort_values(by='Lower Risk', ascending=False)  

# Step 2: Calculate the total number of species for each group  
total_species = grouped_data.sum(axis=1)  

# Step 3: Create the stacked bar plot  
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(20, 12), alpha=0.7)  

# Step 4: Overlay the percentages for the "Threatened" category  
if 'Threatened' in grouped_data.columns:  
    for i in range(len(grouped_data)):  
        threatened_value = grouped_data.iloc[i]['Threatened']  
        if threatened_value > 0:  # Only display percentage if there is a value  
            percentage = (threatened_value / total_species[i]) * 100  
            ax.text(i, threatened_value + 1, f'{percentage:.1f}%', ha='center', va='bottom')  

# Step 5: Customize the plot  
plt.title('Stacked Bar Plot of Group Name by Aggregated Category')  
plt.xlabel('Group Name')  
plt.ylabel('Number of Species')  
plt.legend(title='Aggregated Category')  
plt.xticks(rotation=45)  
plt.tight_layout()  # Adjust layout to make room for the labels  

# Step 6: Show the plot  
plt.show()

# %% [markdown]
# ### Fungi DSI

# %%
fungi_DSI = df_ncbi_lineage_with_iucn_assessed[df_ncbi_lineage_with_iucn_assessed['Kingdom name'] == 'Fungi']

# %%
# Count the occurrences of each category  
category_counts = fungi_DSI['Aggregated_Category'].value_counts()  

# Calculate percentages  
total_counts = category_counts.sum()  
percentages = (category_counts / total_counts) * 100  

# Create a bar plot  
plt.figure(figsize=(10, 6))  
ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')  
plt.title('Distribution of Red List Categories')  
plt.xlabel('Red List Category')  
plt.ylabel('Count')  
plt.xticks(rotation=45)  

# Display percentages on the bars  
for p in ax.patches:  
    ax.annotate(f'{p.get_height()} ({percentages[category_counts.index[int(p.get_x() + p.get_width() / 2)]]:.1f}%)',   
                (p.get_x() + p.get_width() / 2., p.get_height()),   
                ha='center', va='bottom', fontsize=10)  

plt.show()
# Out:
# <ipython-input-198-a0251f1a4be4>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
fungi_DSI['Group name'].value_counts()
# Out:
# Group name
# basidiomycete fungi    352
# ascomycete fungi        89
# Name: count, dtype: int64

# %%
# Count occurrences of each Aggregated_Category within each Group name  
grouped_data = fungi_DSI.groupby(['Group name', 'Aggregated_Category']).size().unstack(fill_value=0).sort_values(by='Lower Risk', ascending=False)  

# Step 2: Calculate the total number of species for each group  
total_species = grouped_data.sum(axis=1)  

# Step 3: Create the stacked bar plot  
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(20, 12), alpha=0.7)  

# Step 4: Overlay the percentages for the "Threatened" category  
if 'Threatened' in grouped_data.columns:  
    for i in range(len(grouped_data)):  
        threatened_value = grouped_data.iloc[i]['Threatened']  
        if threatened_value > 0:  # Only display percentage if there is a value  
            percentage = (threatened_value / total_species[i]) * 100  
            ax.text(i, threatened_value + 1, f'{percentage:.1f}%', ha='center', va='bottom')  

# Step 5: Customize the plot  
plt.title('Stacked Bar Plot of Group Name by Aggregated Category')  
plt.xlabel('Group Name')  
plt.ylabel('Number of Species')  
plt.legend(title='Aggregated Category')  
plt.xticks(rotation=45)  
plt.tight_layout()  # Adjust layout to make room for the labels  

# Step 6: Show the plot  
plt.show()

# %% [markdown]
# ### Fungi+Plants DSI

# %%
fungi_and_plants_DSI = pd.concat([plants_DSI, fungi_DSI])
# Count the occurrences of each category  
category_counts = fungi_and_plants_DSI['Aggregated_Category'].value_counts()  

# Calculate percentages  
total_counts = category_counts.sum()  
percentages = (category_counts / total_counts) * 100  

# Create a bar plot  
plt.figure(figsize=(10, 6))  
ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')  
plt.title('Distribution of Red List Categories')  
plt.xlabel('Red List Category')  
plt.ylabel('Count')  
plt.xticks(rotation=45)  

# Display percentages on the bars  
for p in ax.patches:  
    ax.annotate(f'{p.get_height()} ({percentages[category_counts.index[int(p.get_x() + p.get_width() / 2)]]:.1f}%)',   
                (p.get_x() + p.get_width() / 2., p.get_height()),   
                ha='center', va='bottom', fontsize=10)  

plt.show()
# Out:
# <ipython-input-201-8ff13d3c173e>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
# Count occurrences of each Aggregated_Category within each Group name  
grouped_data = fungi_and_plants_DSI.groupby(['Group name', 'Aggregated_Category']).size().unstack(fill_value=0).sort_values(by='Lower Risk', ascending=False)  

# Step 2: Calculate the total number of species for each group  
total_species = grouped_data.sum(axis=1)  

# Step 3: Create the stacked bar plot  
ax = grouped_data.plot(kind='bar', stacked=True, figsize=(20, 12), alpha=0.7)  

# Step 4: Overlay the percentages for the "Threatened" category  
if 'Threatened' in grouped_data.columns:  
    for i in range(len(grouped_data)):  
        threatened_value = grouped_data.iloc[i]['Threatened']  
        if threatened_value > 0:  # Only display percentage if there is a value  
            percentage = (threatened_value / total_species[i]) * 100  
            ax.text(i, threatened_value + 1, f'{percentage:.1f}%', ha='center', va='bottom')  

# Step 5: Customize the plot  
plt.title('Stacked Bar Plot of Group Name by Aggregated Category')  
plt.xlabel('Group Name')  
plt.ylabel('Number of Species')  
plt.legend(title='Aggregated Category')  
plt.xticks(rotation=45)  
plt.tight_layout()  # Adjust layout to make room for the labels  

# Step 6: Show the plot  
plt.show()

# %%
fungi_and_plants_DSI['Aggregated_Category_Species'] = 'Plants and Fungi'

# %% [markdown]
# ### All together

# %%
all_species = pd.concat([fungi_and_plants_DSI, marine_DSI, terrestrial_DSI])

# %%
all_species

# %%
category_counts = all_species.groupby(['Aggregated_Category_Species', 'Aggregated_Category']).size().reset_index(name='Count')  

# Calculate percentages within each species group  
total_counts = category_counts.groupby('Aggregated_Category_Species')['Count'].transform('sum')  
# category_counts['Percentage'] = (category_counts['Count'] / total_counts) * 100  

# Define the order of species groups and the corresponding colors  
species_order = ['Marine species', 'Plants and Fungi', 'Other terrestrial species']  # Define the desired order  
category_order = ['Lower Risk', 'Threatened', 'Extinct', 'Data Deficient']  
colors = ['#66c2a5', '#fc8d62', '#e41a1c', '#377eb8']   

# Set the order of the species groups in the DataFrame  
category_counts['Aggregated_Category_Species'] = pd.Categorical(category_counts['Aggregated_Category_Species'], categories=species_order, ordered=True)  

plt.rcParams["font.family"] = "Arial"   

# Create a grouped bar plot  
plt.figure(figsize=(18, 12))  
ax = sns.barplot(data=category_counts,   
                 x='Aggregated_Category_Species',   
                 y='Count',   
                 hue='Aggregated_Category',   
                 hue_order=category_order,  # Set the order of the hue  
                 palette=colors)  # Set the custom color palette  

# Increase font sizes  
label_fontsize = 20  
tick_fontsize = 18  
annotation_fontsize = 16  
legend_title_fontsize = 20  # Increased font size for legend title  

# Add title and labels  
# plt.title('Red List Categories by Species Group', fontsize=title_fontsize)  
plt.xlabel('Species Group', fontsize=label_fontsize)  
plt.ylabel('Unique species counts', fontsize=label_fontsize)  
plt.xticks(fontsize=tick_fontsize)  
plt.yticks(fontsize=tick_fontsize)  # Increase y-tick font size  

# Display counts on the bars  
for p in ax.patches:  
    height = p.get_height()  
    ax.annotate(f'{height:.0f}',   
                (p.get_x() + p.get_width() / 2., height),   
                ha='center', va='bottom', fontsize=annotation_fontsize)  

# Add legend and adjust layout  
plt.legend(title='Red List Category', bbox_to_anchor=(0.78, 0.95), loc='upper left', fontsize=label_fontsize, title_fontsize=legend_title_fontsize)  
# plt.tight_layout()  

# Save the plot as an SVG file with a white background  
plt.savefig('red_list_categories_by_species_group.svg', format='svg', facecolor='white')  

# Show the plot  
plt.show()

# %%
all_species['Aggregated_Category_Species'].value_counts()
# Out:
# Aggregated_Category_Species
# Plants and Fungi             22240
# Other terrestrial species    22012
# Marine species               17662
# Name: count, dtype: int64

# %%
all_species[(all_species['Aggregated_Category_Species'] == 'Marine species')&(all_species['Aggregated_Category'] == 'Extinct')]
# Out:
#         Unnamed: 0    Taxid CODE                    ORGANISM     Rank  \
# 1911          2773    66189  VRT           Chelonoidis niger  SPECIES
# 29875        41398   348708  VRT        Coregonus oxyrinchus  SPECIES
# 31815        44086     9909  MAM             Bos primigenius  SPECIES
# 39086        54134  1483067  VRT           Luciobarbus nasus  SPECIES
# 41923        58242   115942  INV          Achatinella livida  SPECIES
# 62181        83185    43332  MAM        Elaphurus davidianus  SPECIES
# 66496        88187    62061  VRT         Acipenser dabryanus  SPECIES
# 76887       103069   208353  VRT           Skiffia francesae  SPECIES
# 77258       103656   106734  VRT      Chelonoidis abingdonii  SPECIES
# 94559       127854   986338  INV     Aylacostoma chloroticum  SPECIES
# 108683      147293   457569  INV                Partula faba  SPECIES
# 109262      148166   180174  VRT         Cylindraspis inepta  SPECIES
# 125548      171496    32473  VRT      Xiphophorus couchianus  SPECIES
# 153199      207012  2762490  INV      Auriculella uniplicata  SPECIES
# 172106      229345  2547733  VRT           Chasmistes muriei  SPECIES
# 208437      275087   311467  VRT               Chitala lopis  SPECIES
# 252046      351010  1482979  VRT             Alosa vistonica  SPECIES
# 257337      359087  1421131  INV               Lottia alveus  SPECIES
# 261632      365804   293135  INV    Pleurobema troschelianum  SPECIES
# 269448      377737   684686  INV          Littoraria flammea  SPECIES
# 345755      489069   861763  VRT             Coregonus renke  SPECIES
# 345900      489225   861791  VRT          Coregonus zugensis  SPECIES
# 353904      509494  1803929  VRT       Scardinius racovitzai  SPECIES
# 374975      544545  2972643  VRT              Salmo pallaryi  SPECIES
# 381703      553556   145554  INV           Partula suturalis  SPECIES
# 385560      559323   293129  INV        Pleurobema perovatum  SPECIES
# 390301      566533   149962  INV             Partula tristis  SPECIES
# 391362      568122    64553  VRT     Ctenochromis pectoralis  SPECIES
# 431197      636829   457567  INV           Partula dentifera  SPECIES
# 434694      645614   543136  INV            Partula aurantia  SPECIES
# 434695      645615   149955  INV           Partula mirabilis  SPECIES
# 436582      651920   208360  VRT           Allotoca goslinei  SPECIES
# 598912      859974   180175  VRT         Cylindraspis indica  SPECIES
# 598913      859975   180178  VRT       Cylindraspis vosmaeri  SPECIES
# 629729      915496  2968121  INV  Graecoanatolica macedonica  SPECIES
# 633793      922728   180177  VRT     Cylindraspis triserrata  SPECIES
# 633794      922729   180176  VRT      Cylindraspis peltastes  SPECIES
# 669143      990731   425792  INV            Partula producta  SPECIES
# 676180     1001902  2996152  VRT    Prototroctes oxyrhynchus  SPECIES
# 683617     1013150   149953  INV                Partula hebe  SPECIES
# 782320     1161453    69305  MAM             Gazella saudiya  SPECIES
# 788832     1172942  2184430  VRT    Triplophysa cuneicephala  SPECIES
# 844860     1270474  1840704  INV     Aylacostoma stigmaticum  SPECIES
# 850047     1284338   268257  VRT  Pseudophoxinus handlirschi  SPECIES
# 901800     1352720   166927  INV             Partula turgida  SPECIES
# 956526     1424437  1278982  VRT      Oncorhynchus kawamurae  SPECIES
#
#                           Group name Superkingdom name Kingdom name  \
# 1911                         turtles         Eukaryota      Metazoa
# 29875                    bony fishes         Eukaryota      Metazoa
# 31815   even-toed ungulates & whales         Eukaryota      Metazoa
# 39086                    bony fishes         Eukaryota      Metazoa
# 41923                     gastropods         Eukaryota      Metazoa
# 62181   even-toed ungulates & whales         Eukaryota      Metazoa
# 66496                    bony fishes         Eukaryota      Metazoa
# 76887                    bony fishes         Eukaryota      Metazoa
# 77258                        turtles         Eukaryota      Metazoa
# 94559                     gastropods         Eukaryota      Metazoa
# 108683                    gastropods         Eukaryota      Metazoa
# 109262                       turtles         Eukaryota      Metazoa
# 125548                   bony fishes         Eukaryota      Metazoa
# 153199                    gastropods         Eukaryota      Metazoa
# 172106                   bony fishes         Eukaryota      Metazoa
# 208437                   bony fishes         Eukaryota      Metazoa
# 252046                   bony fishes         Eukaryota      Metazoa
# 257337                    gastropods         Eukaryota      Metazoa
# 261632                      bivalves         Eukaryota      Metazoa
# 269448                    gastropods         Eukaryota      Metazoa
# 345755                   bony fishes         Eukaryota      Metazoa
# 345900                   bony fishes         Eukaryota      Metazoa
# 353904                   bony fishes         Eukaryota      Metazoa
# 374975                   bony fishes         Eukaryota      Metazoa
# 381703                    gastropods         Eukaryota      Metazoa
# 385560                      bivalves         Eukaryota      Metazoa
# 390301                    gastropods         Eukaryota      Metazoa
# 391362                   bony fishes         Eukaryota      Metazoa
# 431197                    gastropods         Eukaryota      Metazoa
# 434694                    gastropods         Eukaryota      Metazoa
# 434695                    gastropods         Eukaryota      Metazoa
# 436582                   bony fishes         Eukaryota      Metazoa
# 598912                       turtles         Eukaryota      Metazoa
# 598913                       turtles         Eukaryota      Metazoa
# 629729                    gastropods         Eukaryota      Metazoa
# 633793                       turtles         Eukaryota      Metazoa
# 633794                       turtles         Eukaryota      Metazoa
# 669143                    gastropods         Eukaryota      Metazoa
# 676180                   bony fishes         Eukaryota      Metazoa
# 683617                    gastropods         Eukaryota      Metazoa
# 782320  even-toed ungulates & whales         Eukaryota      Metazoa
# 788832                   bony fishes         Eukaryota      Metazoa
# 844860                    gastropods         Eukaryota      Metazoa
# 850047                   bony fishes         Eukaryota      Metazoa
# 901800                    gastropods         Eukaryota      Metazoa
# 956526                   bony fishes         Eukaryota      Metazoa
#
#        Phylum name   Class name          Order name     Family name  \
# 1911      Chordata          NaN          Testudines    Testudinidae
# 29875     Chordata  Actinopteri       Salmoniformes      Salmonidae
# 31815     Chordata     Mammalia        Artiodactyla         Bovidae
# 39086     Chordata  Actinopteri       Cypriniformes      Cyprinidae
# 41923     Mollusca   Gastropoda     Stylommatophora  Achatinellidae
# 62181     Chordata     Mammalia        Artiodactyla        Cervidae
# 66496     Chordata  Actinopteri    Acipenseriformes   Acipenseridae
# 76887     Chordata  Actinopteri  Cyprinodontiformes       Goodeidae
# 77258     Chordata          NaN          Testudines    Testudinidae
# 94559     Mollusca   Gastropoda                 NaN       Thiaridae
# 108683    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 109262    Chordata          NaN          Testudines    Testudinidae
# 125548    Chordata  Actinopteri  Cyprinodontiformes     Poeciliidae
# 153199    Mollusca   Gastropoda     Stylommatophora  Achatinellidae
# 172106    Chordata  Actinopteri       Cypriniformes    Catostomidae
# 208437    Chordata  Actinopteri   Osteoglossiformes    Notopteridae
# 252046    Chordata  Actinopteri        Clupeiformes       Clupeidae
# 257337    Mollusca   Gastropoda                 NaN       Lottiidae
# 261632    Mollusca     Bivalvia            Unionida       Unionidae
# 269448    Mollusca   Gastropoda     Littorinimorpha    Littorinidae
# 345755    Chordata  Actinopteri       Salmoniformes      Salmonidae
# 345900    Chordata  Actinopteri       Salmoniformes      Salmonidae
# 353904    Chordata  Actinopteri       Cypriniformes     Leuciscidae
# 374975    Chordata  Actinopteri       Salmoniformes      Salmonidae
# 381703    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 385560    Mollusca     Bivalvia            Unionida       Unionidae
# 390301    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 391362    Chordata  Actinopteri        Cichliformes       Cichlidae
# 431197    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 434694    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 434695    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 436582    Chordata  Actinopteri  Cyprinodontiformes       Goodeidae
# 598912    Chordata          NaN          Testudines    Testudinidae
# 598913    Chordata          NaN          Testudines    Testudinidae
# 629729    Mollusca   Gastropoda     Littorinimorpha     Hydrobiidae
# 633793    Chordata          NaN          Testudines    Testudinidae
# 633794    Chordata          NaN          Testudines    Testudinidae
# 669143    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 676180    Chordata  Actinopteri        Osmeriformes   Retropinnidae
# 683617    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 782320    Chordata     Mammalia        Artiodactyla         Bovidae
# 788832    Chordata  Actinopteri       Cypriniformes   Nemacheilidae
# 844860    Mollusca   Gastropoda                 NaN       Thiaridae
# 850047    Chordata  Actinopteri       Cypriniformes     Leuciscidae
# 901800    Mollusca   Gastropoda     Stylommatophora      Partulidae
# 956526    Chordata  Actinopteri       Salmoniformes      Salmonidae
#
#              Genus name                Species name  internalTaxonId  \
# 1911        Chelonoidis           Chelonoidis niger           9023.0
# 29875         Coregonus        Coregonus oxyrinchus           5380.0
# 31815               Bos             Bos primigenius         136721.0
# 39086       Luciobarbus           Luciobarbus nasus      217675561.0
# 41923       Achatinella          Achatinella livida            189.0
# 62181         Elaphurus        Elaphurus davidianus           7121.0
# 66496         Acipenser         Acipenser dabryanus            231.0
# 76887           Skiffia           Skiffia francesae          20285.0
# 77258       Chelonoidis      Chelonoidis abingdonii           9017.0
# 94559       Aylacostoma     Aylacostoma chloroticum          29612.0
# 108683          Partula                Partula faba          16288.0
# 109262     Cylindraspis         Cylindraspis inepta           6062.0
# 125548      Xiphophorus      Xiphophorus couchianus          23156.0
# 153199      Auriculella      Auriculella uniplicata           2412.0
# 172106       Chasmistes           Chasmistes muriei           4589.0
# 208437          Chitala               Chitala lopis      157719927.0
# 252046            Alosa             Alosa vistonica          61393.0
# 257337           Lottia               Lottia alveus          12382.0
# 261632       Pleurobema    Pleurobema troschelianum          17694.0
# 269448       Littoraria          Littoraria flammea          12242.0
# 345755        Coregonus             Coregonus renke         135513.0
# 345900        Coregonus          Coregonus zugensis      232858400.0
# 353904       Scardinius       Scardinius racovitzai          19948.0
# 374975            Salmo              Salmo pallaryi          61190.0
# 381703          Partula           Partula suturalis          16281.0
# 385560       Pleurobema        Pleurobema perovatum          17689.0
# 390301          Partula             Partula tristis          16330.0
# 391362     Ctenochromis     Ctenochromis pectoralis           9722.0
# 431197          Partula           Partula dentifera      103142760.0
# 434694          Partula            Partula aurantia          16272.0
# 434695          Partula           Partula mirabilis          16277.0
# 436582         Allotoca           Allotoca goslinei         191696.0
# 598912     Cylindraspis         Cylindraspis indica           6061.0
# 598913     Cylindraspis       Cylindraspis vosmaeri           6065.0
# 629729  Graecoanatolica  Graecoanatolica macedonica          41027.0
# 633793     Cylindraspis     Cylindraspis triserrata           6064.0
# 633794     Cylindraspis      Cylindraspis peltastes           6063.0
# 669143          Partula            Partula producta          16322.0
# 676180     Prototroctes    Prototroctes oxyrhynchus          18384.0
# 683617          Partula                Partula hebe          16275.0
# 782320          Gazella             Gazella saudiya           8980.0
# 788832      Triplophysa    Triplophysa cuneicephala      212912045.0
# 844860      Aylacostoma     Aylacostoma stigmaticum          29613.0
# 850047   Pseudophoxinus  Pseudophoxinus handlirschi          40747.0
# 901800          Partula             Partula turgida          16331.0
# 956526     Oncorhynchus      Oncorhynchus kawamurae      110463465.0
#
#        populationTrend      redlistCategory Aggregated_Category  \
# 1911               NaN              Extinct             Extinct
# 29875              NaN              Extinct             Extinct
# 31815              NaN              Extinct             Extinct
# 39086              NaN              Extinct             Extinct
# 41923              NaN              Extinct             Extinct
# 62181              NaN  Extinct in the Wild             Extinct
# 66496              NaN  Extinct in the Wild             Extinct
# 76887              NaN  Extinct in the Wild             Extinct
# 77258              NaN              Extinct             Extinct
# 94559              NaN  Extinct in the Wild             Extinct
# 108683             NaN              Extinct             Extinct
# 109262             NaN              Extinct             Extinct
# 125548             NaN  Extinct in the Wild             Extinct
# 153199             NaN              Extinct             Extinct
# 172106             NaN              Extinct             Extinct
# 208437             NaN              Extinct             Extinct
# 252046             NaN              Extinct             Extinct
# 257337             NaN              Extinct             Extinct
# 261632             NaN              Extinct             Extinct
# 269448             NaN              Extinct             Extinct
# 345755             NaN              Extinct             Extinct
# 345900             NaN              Extinct             Extinct
# 353904             NaN  Extinct in the Wild             Extinct
# 374975             NaN              Extinct             Extinct
# 381703             NaN  Extinct in the Wild             Extinct
# 385560             NaN              Extinct             Extinct
# 390301             NaN              Extinct             Extinct
# 391362             NaN              Extinct             Extinct
# 431197             NaN              Extinct             Extinct
# 434694             NaN              Extinct             Extinct
# 434695             NaN  Extinct in the Wild             Extinct
# 436582             NaN  Extinct in the Wild             Extinct
# 598912             NaN              Extinct             Extinct
# 598913             NaN              Extinct             Extinct
# 629729             NaN              Extinct             Extinct
# 633793             NaN              Extinct             Extinct
# 633794             NaN              Extinct             Extinct
# 669143             NaN              Extinct             Extinct
# 676180         Unknown              Extinct             Extinct
# 683617             NaN  Extinct in the Wild             Extinct
# 782320             NaN              Extinct             Extinct
# 788832             NaN              Extinct             Extinct
# 844860             NaN  Extinct in the Wild             Extinct
# 850047             NaN              Extinct             Extinct
# 901800             NaN              Extinct             Extinct
# 956526             NaN  Extinct in the Wild             Extinct
#
#        Aggregated_Category_Species
# 1911                Marine species
# 29875               Marine species
# 31815               Marine species
# 39086               Marine species
# 41923               Marine species
# 62181               Marine species
# 66496               Marine species
# 76887               Marine species
# 77258               Marine species
# 94559               Marine species
# 108683              Marine species
# 109262              Marine species
# 125548              Marine species
# 153199              Marine species
# 172106              Marine species
# 208437              Marine species
# 252046              Marine species
# 257337              Marine species
# 261632              Marine species
# 269448              Marine species
# 345755              Marine species
# 345900              Marine species
# 353904              Marine species
# 374975              Marine species
# 381703              Marine species
# 385560              Marine species
# 390301              Marine species
# 391362              Marine species
# 431197              Marine species
# 434694              Marine species
# 434695              Marine species
# 436582              Marine species
# 598912              Marine species
# 598913              Marine species
# 629729              Marine species
# 633793              Marine species
# 633794              Marine species
# 669143              Marine species
# 676180              Marine species
# 683617              Marine species
# 782320              Marine species
# 788832              Marine species
# 844860              Marine species
# 850047              Marine species
# 901800              Marine species
# 956526              Marine species

# %%
all_species[(all_species['Aggregated_Category_Species'] == 'Plants and Fungi')&(all_species['Aggregated_Category'] == 'Extinct')]
# Out:
#         Unnamed: 0    Taxid CODE                       ORGANISM     Rank  \
# 83209       111683    82448  PLN     Trochetiopsis erythroxylon  SPECIES
# 84098       113063   904444  PLN             Lachanodes arborea  SPECIES
# 84505       113548   479408  PLN         Camellia amplexicaulis  SPECIES
# 90748       121465    41689  PLN             Brugmansia arborea  SPECIES
# 107080      145031   684373  PLN              Mangifera casturi  SPECIES
# 141137      192608   382137  PLN          Furcraea macdougallii  SPECIES
# 142600      194376   905076  PLN          Brugmansia suaveolens  SPECIES
# 154640      208699   380070  PLN         Geocaryum bornmuelleri  SPECIES
# 211724      280014    55774  PLN             Bromus interruptus  SPECIES
# 211887      280221   251413  PLN         Encephalartos heenanii  SPECIES
# 218856      288837  1128770  PLN  Encephalartos brevifoliolatus  SPECIES
# 231472      309380   351336  PLN     Centaurea pseudoleucolepis  SPECIES
# 232817      311986   101953  PLN         Rhododendron kanehirae  SPECIES
# 234622      314723   179231  PLN           Encephalartos woodii  SPECIES
# 241483      325783   182302  PLN           Franklinia alatamaha  SPECIES
# 245255      331163   126429  PLN            Hesperelaea palmeri  SPECIES
# 279955      395070   224335  PLN                Arachis rigonii  SPECIES
# 280223      395403  3128777  PLN             Syzygium humblotii  SPECIES
# 333617      471202  1073791  PLN          Adiantum lianxianense  SPECIES
# 369190      532701  1869362  PLN          Diplazium laffanianum  SPECIES
# 376600      546441   540794  PLN           Brugmansia sanguinea  SPECIES
# 409320      598191   179218  PLN     Encephalartos nubimontanus  SPECIES
# 410256      599529  1128774  PLN         Encephalartos relictus  SPECIES
# 431507      637499    76571  PLN             Brighamia insignis  SPECIES
# 445209      664082   162646  PLN              Amherstia nobilis  SPECIES
# 525550      764667    55775  PLN              Bromus bromoideus  SPECIES
# 593063      848037   931238  PLN                Sicyos villosus  SPECIES
# 620194      901309  2732283  PLN                  Acaena exigua  SPECIES
# 670303      993803  2866388  PLN             Pradosia glaziovii  SPECIES
# 685786     1016443  2695074  PLN                   Agave lurida  SPECIES
# 697283     1043865   368924  PLN              Delissea undulata  SPECIES
# 741055     1093477  1689661  PLN         Brugmansia vulcanicola  SPECIES
# 765420     1132343  2909850  PLN             Trilepidea adamsii  SPECIES
#
#          Group name Superkingdom name   Kingdom name   Phylum name  \
# 83209      eudicots         Eukaryota  Viridiplantae  Streptophyta
# 84098      eudicots         Eukaryota  Viridiplantae  Streptophyta
# 84505      eudicots         Eukaryota  Viridiplantae  Streptophyta
# 90748      eudicots         Eukaryota  Viridiplantae  Streptophyta
# 107080     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 141137     monocots         Eukaryota  Viridiplantae  Streptophyta
# 142600     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 154640     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 211724     monocots         Eukaryota  Viridiplantae  Streptophyta
# 211887  seed plants         Eukaryota  Viridiplantae  Streptophyta
# 218856  seed plants         Eukaryota  Viridiplantae  Streptophyta
# 231472     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 232817     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 234622  seed plants         Eukaryota  Viridiplantae  Streptophyta
# 241483     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 245255     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 279955     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 280223     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 333617        ferns         Eukaryota  Viridiplantae  Streptophyta
# 369190        ferns         Eukaryota  Viridiplantae  Streptophyta
# 376600     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 409320  seed plants         Eukaryota  Viridiplantae  Streptophyta
# 410256  seed plants         Eukaryota  Viridiplantae  Streptophyta
# 431507     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 445209     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 525550     monocots         Eukaryota  Viridiplantae  Streptophyta
# 593063     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 620194     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 670303     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 685786     monocots         Eukaryota  Viridiplantae  Streptophyta
# 697283     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 741055     eudicots         Eukaryota  Viridiplantae  Streptophyta
# 765420     eudicots         Eukaryota  Viridiplantae  Streptophyta
#
#             Class name    Order name    Family name     Genus name  \
# 83209    Magnoliopsida      Malvales      Malvaceae  Trochetiopsis
# 84098    Magnoliopsida     Asterales     Asteraceae     Lachanodes
# 84505    Magnoliopsida      Ericales       Theaceae       Camellia
# 90748    Magnoliopsida     Solanales     Solanaceae     Brugmansia
# 107080   Magnoliopsida    Sapindales  Anacardiaceae      Mangifera
# 141137   Magnoliopsida   Asparagales   Asparagaceae       Furcraea
# 142600   Magnoliopsida     Solanales     Solanaceae     Brugmansia
# 154640   Magnoliopsida       Apiales       Apiaceae      Geocaryum
# 211724   Magnoliopsida        Poales        Poaceae         Bromus
# 211887     Cycadopsida     Cycadales      Zamiaceae  Encephalartos
# 218856     Cycadopsida     Cycadales      Zamiaceae  Encephalartos
# 231472   Magnoliopsida     Asterales     Asteraceae      Centaurea
# 232817   Magnoliopsida      Ericales      Ericaceae   Rhododendron
# 234622     Cycadopsida     Cycadales      Zamiaceae  Encephalartos
# 241483   Magnoliopsida      Ericales       Theaceae     Franklinia
# 245255   Magnoliopsida      Lamiales       Oleaceae    Hesperelaea
# 279955   Magnoliopsida       Fabales       Fabaceae        Arachis
# 280223   Magnoliopsida      Myrtales      Myrtaceae       Syzygium
# 333617  Polypodiopsida  Polypodiales    Pteridaceae       Adiantum
# 369190  Polypodiopsida  Polypodiales    Athyriaceae      Diplazium
# 376600   Magnoliopsida     Solanales     Solanaceae     Brugmansia
# 409320     Cycadopsida     Cycadales      Zamiaceae  Encephalartos
# 410256     Cycadopsida     Cycadales      Zamiaceae  Encephalartos
# 431507   Magnoliopsida     Asterales  Campanulaceae      Brighamia
# 445209   Magnoliopsida       Fabales       Fabaceae      Amherstia
# 525550   Magnoliopsida        Poales        Poaceae         Bromus
# 593063   Magnoliopsida  Cucurbitales  Cucurbitaceae         Sicyos
# 620194   Magnoliopsida       Rosales       Rosaceae         Acaena
# 670303   Magnoliopsida      Ericales     Sapotaceae       Pradosia
# 685786   Magnoliopsida   Asparagales   Asparagaceae          Agave
# 697283   Magnoliopsida     Asterales  Campanulaceae       Delissea
# 741055   Magnoliopsida     Solanales     Solanaceae     Brugmansia
# 765420   Magnoliopsida    Santalales   Loranthaceae     Trilepidea
#
#                          Species name  internalTaxonId populationTrend  \
# 83209      Trochetiopsis erythroxylon          30560.0             NaN
# 84098              Lachanodes arborea          37595.0             NaN
# 84505          Camellia amplexicaulis         191323.0             NaN
# 90748              Brugmansia arborea       51247708.0             NaN
# 107080              Mangifera casturi          32059.0             NaN
# 141137          Furcraea macdougallii      136808736.0             NaN
# 142600          Brugmansia suaveolens       51247699.0             NaN
# 154640         Geocaryum bornmuelleri      232118222.0             NaN
# 211724             Bromus interruptus         165247.0             NaN
# 211887         Encephalartos heenanii          41888.0             NaN
# 218856  Encephalartos brevifoliolatus          41882.0             NaN
# 231472     Centaurea pseudoleucolepis         165235.0             NaN
# 232817         Rhododendron kanehirae          37821.0             NaN
# 234622           Encephalartos woodii          41881.0             NaN
# 241483           Franklinia alatamaha          30408.0             NaN
# 245255            Hesperelaea palmeri      126608606.0             NaN
# 279955                Arachis rigonii       62758119.0             NaN
# 280223             Syzygium humblotii      168623053.0             NaN
# 333617          Adiantum lianxianense          46603.0             NaN
# 369190          Diplazium laffanianum       56605187.0             NaN
# 376600           Brugmansia sanguinea       51247690.0             NaN
# 409320     Encephalartos nubimontanus          41896.0             NaN
# 410256         Encephalartos relictus          41764.0             NaN
# 431507             Brighamia insignis          44080.0             NaN
# 445209              Amherstia nobilis      226776565.0             NaN
# 525550              Bromus bromoideus         165228.0             NaN
# 593063                Sicyos villosus       61503076.0             NaN
# 620194                  Acaena exigua          44072.0             NaN
# 670303             Pradosia glaziovii          35920.0             NaN
# 685786                   Agave lurida      123986030.0             NaN
# 697283              Delissea undulata          34040.0             NaN
# 741055         Brugmansia vulcanicola       51247712.0             NaN
# 765420             Trilepidea adamsii       62798347.0             NaN
#
#             redlistCategory Aggregated_Category Aggregated_Category_Species
# 83209   Extinct in the Wild             Extinct            Plants and Fungi
# 84098   Extinct in the Wild             Extinct            Plants and Fungi
# 84505   Extinct in the Wild             Extinct            Plants and Fungi
# 90748   Extinct in the Wild             Extinct            Plants and Fungi
# 107080  Extinct in the Wild             Extinct            Plants and Fungi
# 141137  Extinct in the Wild             Extinct            Plants and Fungi
# 142600  Extinct in the Wild             Extinct            Plants and Fungi
# 154640              Extinct             Extinct            Plants and Fungi
# 211724  Extinct in the Wild             Extinct            Plants and Fungi
# 211887  Extinct in the Wild             Extinct            Plants and Fungi
# 218856  Extinct in the Wild             Extinct            Plants and Fungi
# 231472              Extinct             Extinct            Plants and Fungi
# 232817  Extinct in the Wild             Extinct            Plants and Fungi
# 234622  Extinct in the Wild             Extinct            Plants and Fungi
# 241483  Extinct in the Wild             Extinct            Plants and Fungi
# 245255              Extinct             Extinct            Plants and Fungi
# 279955  Extinct in the Wild             Extinct            Plants and Fungi
# 280223              Extinct             Extinct            Plants and Fungi
# 333617              Extinct             Extinct            Plants and Fungi
# 369190  Extinct in the Wild             Extinct            Plants and Fungi
# 376600  Extinct in the Wild             Extinct            Plants and Fungi
# 409320  Extinct in the Wild             Extinct            Plants and Fungi
# 410256  Extinct in the Wild             Extinct            Plants and Fungi
# 431507  Extinct in the Wild             Extinct            Plants and Fungi
# 445209  Extinct in the Wild             Extinct            Plants and Fungi
# 525550  Extinct in the Wild             Extinct            Plants and Fungi
# 593063              Extinct             Extinct            Plants and Fungi
# 620194              Extinct             Extinct            Plants and Fungi
# 670303              Extinct             Extinct            Plants and Fungi
# 685786  Extinct in the Wild             Extinct            Plants and Fungi
# 697283              Extinct             Extinct            Plants and Fungi
# 741055  Extinct in the Wild             Extinct            Plants and Fungi
# 765420              Extinct             Extinct            Plants and Fungi

# %%
all_species[(all_species['Aggregated_Category_Species'] == 'Terrestrial species')&(all_species['Aggregated_Category'] == 'Extinct')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Taxid, CODE, ORGANISM, Rank, Group name, Superkingdom name, Kingdom name, Phylum name, Class name, Order name, Family name, Genus name, Species name, internalTaxonId, populationTrend, redlistCategory, Aggregated_Category, Aggregated_Category_Species]
# Index: []

# %% [markdown]
# ### I
